# %%
redes = [63, 56, 49, 42, 35, 28, 21, 14, 7]
Lambdas = [0.001]

for r1 in redes:
    
    for r2 in redes:
        
        for r3 in redes:
            
            for r4 in redes:

                r = red_neuronal(4, [r1, r2, r3, r4], 0.12, Ex.shape[1], 4)

                for L in Lambdas:

                    iteraciones = [50, 100, 300, 500]
                    validaciones = []
                    pruebas = []

                    for i in range(len(iteraciones)):
                        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
                        validaciones.append(p1)
                        pruebas.append(p2)

                    plt.figure()
                    plt.title("red: {}".format([r1, r2, r3, r4]))
                    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
                    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
                    plt.show()
# Out:
# (43,)
# (0,)
# (761,)
# (1532,)
# validación = 26.15582191780822
# (35,)
# (0,)
# (775,)
# (1526,)
# prueba = 27.31164383561644
# (742,)
# (461,)
# (514,)
# (619,)
# validación = 32.91952054794521
# (730,)
# (478,)
# (541,)
# (587,)
# prueba = 33.04794520547945
# (589,)
# (518,)
# (674,)
# (555,)
# validación = 69.17808219178082
# (526,)
# (532,)
# (695,)
# (583,)
# prueba = 70.24828767123287
# (609,)
# (553,)
# (599,)
# (575,)
# validación = 72.8167808219178
# (618,)
# (513,)
# (621,)
# (584,)
# prueba = 74.31506849315068
# (0,)
# (1519,)
# (83,)
# (734,)
# validación = 28.809931506849317
# (0,)
# (1539,)
# (89,)
# (708,)
# prueba = 28.852739726027398
# (890,)
# (823,)
# (227,)
# (396,)
# validación = 36.51541095890411
# (885,)
# (808,)
# (220,)
# (423,)
# prueba = 37.88527397260274
# (640,)
# (605,)
# (531,)
# (560,)
# validación = 67.8082191780822
# (614,)
# (567,)
# (542,)
# (613,)
# prueba = 69.30650684931507
# (557,)
# (648,)
# (563,)
# (568,)
# validación = 71.70376712328768
# ...

# %%
63,63,56,63    63,63,63,63   63,63,63,56    74,72
63,63,63,42    73,73
63,63,56,35    76,75
63,63,49,49    75,73
63,63,49,21    73,76
63,63,42,56    74,74
63,63,42,21    73,72
63,63,35,35    73,71
63,63,35,21    73,74
63,63,35,14    74,75
63,63,28,56    74,75
63,63,28,49    72,74
