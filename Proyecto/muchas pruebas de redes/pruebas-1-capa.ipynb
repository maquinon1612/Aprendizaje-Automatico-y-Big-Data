# %%
from creador_redes import *
import loader as ld
import fun_basicas as fun
import matplotlib.pyplot as plt

random_state = 2714
INIT_EPSILON = 0.12

Ex, Ey, Vx, Vy, Px, Py = ld.carga_Numpy(random_state)
y_onehot = fun.one_hot(Ey, 4)


Ex2, scaler = ld.normalizar(Ex)
Vx2 = scaler.transform(Vx)
Px2 = scaler.transform(Px)

# %%
r = red_neuronal(2, [63,63], 0.12, Ex2.shape[1], 4)

iteraciones = [100, 500, 1000, 1500, 2000]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, 0.01, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)

plt.figure()
plt.title("red: {}, Lambda = {}".format([63,63], 0.01))
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (675,)
# (439,)
# (795,)
# (427,)
# validación = 32.36301369863014
# (687,)
# (465,)
# (777,)
# (407,)
# prueba = 33.56164383561644
# (685,)
# (552,)
# (535,)
# (564,)
# validación = 78.08219178082192
# (685,)
# (525,)
# (541,)
# (585,)
# prueba = 79.02397260273972
# (665,)
# (567,)
# (549,)
# (555,)
# validación = 83.81849315068493
# (646,)
# (546,)
# (568,)
# (576,)
# prueba = 85.23116438356165
# (631,)
# (570,)
# (571,)
# (564,)
# validación = 89.12671232876713
# (596,)
# (566,)
# (597,)
# (577,)
# prueba = 90.92465753424658
# (630,)
# (580,)
# (574,)
# (552,)
# validación = 87.5
# (626,)
# (562,)
# (560,)
# (588,)
# prueba = 87.5

# %%
r = red_neuronal(2, [56,63,42], 0.12, Ex2.shape[1], 4)

iteraciones = [100, 500, 1000, 1500, 2000]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, 0.001, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)

plt.figure()
plt.title("red: {}, Lambda = {}".format([56,63,42], 0.001))
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (1583,)
# (152,)
# (90,)
# (511,)
# validación = 30.90753424657534
# (1597,)
# (125,)
# (98,)
# (516,)
# prueba = 31.977739726027398
# (853,)
# (601,)
# (345,)
# (537,)
# validación = 62.328767123287676
# (918,)
# (582,)
# (283,)
# (553,)
# prueba = 62.58561643835616
# (605,)
# (580,)
# (622,)
# (529,)
# validación = 81.67808219178082
# (583,)
# (566,)
# (619,)
# (568,)
# prueba = 82.96232876712328
# (596,)
# (594,)
# (591,)
# (555,)
# validación = 84.46061643835617
# (576,)
# (548,)
# (615,)
# (597,)
# prueba = 86.68664383561644
# (580,)
# (597,)
# (609,)
# (550,)
# validación = 84.20376712328768
# (574,)
# (591,)
# (588,)
# (583,)
# prueba = 86.17294520547945
