# %%
from creador_redes import *
import loader as ld
import fun_basicas as fun
import matplotlib.pyplot as plt

random_state = 2714
INIT_EPSILON = 0.12

Ex, Ey, Vx, Vy, Px, Py = ld.carga_Numpy(random_state)
y_onehot = fun.one_hot(Ey, 4)

# %%
Ex2, scaler = ld.normalizar(Ex)
Vx2 = scaler.transform(Vx)
Px2 = scaler.transform(Px)

# %% [markdown]
# ### combinaciones de dos capas

# %%
redes = [63, 56, 49, 42, 35, 28, 21, 14, 7]
Lambdas = [0.1]

for r1 in redes:
    
    for r2 in redes:

        r = red_neuronal(2, [r1, r2], 0.12, Ex.shape[1], 4)

        for L in Lambdas:

            iteraciones = [50, 100, 300, 500]
            validaciones = []
            pruebas = []

            for i in range(len(iteraciones)):
                p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, L, iteraciones[i], INIT_EPSILON)
                validaciones.append(p1)
                pruebas.append(p2)

        plt.figure()
        plt.title("red: {}".format([r1, r2]))
        plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
        plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
        plt.show()
# Out:
# (416,)
# (906,)
# (231,)
# (783,)
# validación = 32.40582191780822
# (387,)
# (927,)
# (247,)
# (775,)
# prueba = 30.39383561643836
# (725,)
# (558,)
# (420,)
# (633,)
# validación = 53.42465753424658
# (692,)
# (562,)
# (438,)
# (644,)
# prueba = 51.455479452054796
# (625,)
# (547,)
# (591,)
# (573,)
# validación = 72.6027397260274
# (600,)
# (542,)
# (590,)
# (604,)
# prueba = 70.6763698630137
# (606,)
# (597,)
# (557,)
# (576,)
# validación = 67.46575342465754
# (596,)
# (543,)
# (595,)
# (602,)
# prueba = 67.20890410958904
# (917,)
# (418,)
# (223,)
# (778,)
# validación = 32.02054794520548
# (925,)
# (409,)
# (223,)
# (779,)
# prueba = 30.86472602739726
# (572,)
# (241,)
# (825,)
# (698,)
# validación = 55.39383561643836
# (617,)
# (227,)
# (759,)
# (733,)
# prueba = 55.39383561643836
# (628,)
# (583,)
# (569,)
# (556,)
# validación = 70.37671232876713
# (588,)
# (560,)
# (587,)
# (601,)
# prueba = 74.2722602739726
# (610,)
# (592,)
# (583,)
# (551,)
# validación = 69.86301369863014
# (593,)
# (540,)
# (639,)
# (564,)
# prueba = 70.46232876712328
# (610,)
# (360,)
# (258,)
# (1108,)
# validación = 33.04794520547945
# (639,)
# (380,)
# (270,)
# (1047,)
# prueba = 35.273972602739725
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: divide by zero encountered in log
#   s1 = y * np.log(h)
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: invalid value encountered in multiply
#   s1 = y * np.log(h)
# (749,)
# (360,)
# (558,)
# (669,)
# validación = 31.464041095890412
# (770,)
# (345,)
# (574,)
# (647,)
# prueba = 31.37842465753425
# (629,)
# (515,)
# (617,)
# (575,)
# validación = 71.91780821917808
# (604,)
# (546,)
# (585,)
# (601,)
# prueba = 71.83219178082192
# (634,)
# (533,)
# (621,)
# (548,)
# validación = 70.4195205479452
# (601,)
# (527,)
# (636,)
# (572,)
# prueba = 69.34931506849315
# (580,)
# (724,)
# (379,)
# (653,)
# validación = 32.36301369863014
# (564,)
# (690,)
# (363,)
# (719,)
# prueba = 34.97431506849315
# (894,)
# (301,)
# (564,)
# (577,)
# validación = 54.36643835616438
# (888,)
# (306,)
# (541,)
# (601,)
# prueba = 55.7791095890411
# (621,)
# (535,)
# (596,)
# (584,)
# validación = 73.3304794520548
# (619,)
# (510,)
# (589,)
# (618,)
# prueba = 74.44349315068493
# (608,)
# (588,)
# (586,)
# (554,)
# validación = 70.33390410958904
# (608,)
# (578,)
# (593,)
# (557,)
# prueba = 70.11986301369863
# (486,)
# (444,)
# (378,)
# (1028,)
# validación = 33.476027397260275
# (471,)
# (409,)
# (420,)
# (1036,)
# prueba = 34.03253424657534
# (760,)
# (432,)
# (517,)
# (627,)
# validación = 56.54965753424658
# (767,)
# (408,)
# (512,)
# (649,)
# prueba = 56.63527397260274
# (632,)
# (534,)
# (575,)
# (595,)
# validación = 72.30308219178082
# (633,)
# (510,)
# (573,)
# (620,)
# prueba = 70.63356164383562
# (585,)
# (547,)
# (635,)
# (569,)
# validación = 68.79280821917808
# (588,)
# (538,)
# (612,)
# (598,)
# prueba = 68.57876712328768
# (641,)
# (706,)
# (523,)
# (466,)
# validación = 31.549657534246577
# (686,)
# (681,)
# (503,)
# (466,)
# prueba = 32.19178082191781
# (614,)
# (326,)
# (768,)
# (628,)
# validación = 57.79109589041096
# (622,)
# (266,)
# (781,)
# (667,)
# prueba = 58.26198630136986
# (654,)
# (553,)
# (554,)
# (575,)
# validación = 71.06164383561644
# (611,)
# (521,)
# (584,)
# (620,)
# prueba = 73.03082191780823
# (607,)
# (582,)
# (579,)
# (568,)
# validación = 67.89383561643835
# (624,)
# (525,)
# (590,)
# (597,)
# prueba = 66.52397260273972
# (631,)
# (502,)
# (813,)
# (390,)
# validación = 33.34760273972603
# (633,)
# (436,)
# (841,)
# (426,)
# prueba = 34.50342465753425
# (498,)
# (852,)
# (559,)
# (427,)
# validación = 33.34760273972603
# (465,)
# (838,)
# (547,)
# (486,)
# prueba = 33.6472602739726
# (647,)
# (500,)
# (621,)
# (568,)
# validación = 69.77739726027397
# (623,)
# (463,)
# (655,)
# (595,)
# prueba = 70.76198630136986
# (624,)
# (558,)
# (605,)
# (549,)
# validación = 69.56335616438356
# (624,)
# (478,)
# (629,)
# (605,)
# prueba = 70.76198630136986
# (435,)
# (794,)
# (430,)
# (677,)
# validación = 30.43664383561644
# (403,)
# (751,)
# (472,)
# (710,)
# prueba = 29.02397260273973
# (831,)
# (312,)
# (623,)
# (570,)
# validación = 54.409246575342465
# (809,)
# (305,)
# (616,)
# (606,)
# prueba = 53.296232876712324
# (703,)
# (457,)
# (576,)
# (600,)
# validación = 63.2277397260274
# (683,)
# (493,)
# (586,)
# (574,)
# prueba = 65.23972602739725
# (704,)
# (439,)
# (598,)
# (595,)
# validación = 60.23116438356164
# (740,)
# (426,)
# (551,)
# (619,)
# prueba = 62.457191780821915
# (181,)
# (1027,)
# (613,)
# (515,)
# validación = 33.04794520547945
# (166,)
# (1021,)
# (589,)
# (560,)
# prueba = 32.49143835616438
# (586,)
# (376,)
# (549,)
# (825,)
# validación = 44.34931506849315
# (582,)
# (385,)
# (568,)
# (801,)
# prueba = 45.50513698630137
# (840,)
# (253,)
# (644,)
# (599,)
# validación = 50.81335616438356
# (852,)
# (239,)
# (611,)
# (634,)
# prueba = 52.82534246575342
# (884,)
# (155,)
# (655,)
# (642,)
# validación = 50.0
# (857,)
# (141,)
# (653,)
# (685,)
# prueba = 53.42465753424658
# (410,)
# (1085,)
# (204,)
# (637,)
# validación = 31.164383561643838
# (446,)
# (1059,)
# (162,)
# (669,)
# prueba = 32.148972602739725
# (931,)
# (309,)
# (422,)
# (674,)
# validación = 34.28938356164384
# (950,)
# (298,)
# (399,)
# (689,)
# prueba = 36.64383561643836
# (634,)
# (534,)
# (601,)
# (567,)
# validación = 74.65753424657534
# (606,)
# (518,)
# (616,)
# (596,)
# prueba = 75.21404109589042
# (630,)
# (593,)
# (571,)
# (542,)
# validación = 65.28253424657534
# (583,)
# (574,)
# (589,)
# (590,)
# prueba = 67.89383561643835
# (634,)
# (486,)
# (362,)
# (854,)
# validación = 32.61986301369863
# (580,)
# (529,)
# (368,)
# (859,)
# prueba = 31.12157534246575
# (620,)
# (533,)
# (500,)
# (683,)
# validación = 51.284246575342465
# (612,)
# (586,)
# (441,)
# (697,)
# prueba = 53.125
# (651,)
# (538,)
# (579,)
# (568,)
# validación = 72.8167808219178
# (673,)
# (487,)
# (589,)
# (587,)
# prueba = 75.08561643835617
# (580,)
# (591,)
# (606,)
# (559,)
# validación = 66.99486301369863
# (573,)
# (537,)
# (613,)
# (613,)
# prueba = 67.97945205479452
# (262,)
# (825,)
# (721,)
# (528,)
# validación = 32.19178082191781
# (228,)
# (732,)
# (790,)
# (586,)
# prueba = 32.148972602739725
# (621,)
# (378,)
# (779,)
# (558,)
# validación = 45.24828767123288
# (560,)
# (358,)
# (803,)
# (615,)
# prueba = 46.917808219178085
# (666,)
# (534,)
# (570,)
# (566,)
# validación = 72.17465753424658
# (626,)
# (462,)
# (638,)
# (610,)
# prueba = 72.64554794520548
# (584,)
# (570,)
# (614,)
# (568,)
# validación = 68.87842465753424
# (549,)
# (571,)
# (599,)
# (617,)
# prueba = 67.97945205479452
# (542,)
# (625,)
# (478,)
# (691,)
# validación = 36.215753424657535
# (560,)
# (566,)
# (464,)
# (746,)
# prueba = 34.50342465753425
# (547,)
# (520,)
# (244,)
# (1025,)
# validación = 31.80650684931507
# (542,)
# (529,)
# (200,)
# (1065,)
# prueba = 33.9041095890411
# (597,)
# (571,)
# (598,)
# (570,)
# validación = 72.00342465753424
# (618,)
# (548,)
# (599,)
# (571,)
# prueba = 72.73116438356165
# (609,)
# (579,)
# (580,)
# (568,)
# validación = 68.92123287671232
# (608,)
# (568,)
# (570,)
# (590,)
# prueba = 69.4777397260274
# (521,)
# (679,)
# (390,)
# (746,)
# validación = 33.26198630136986
# (533,)
# (636,)
# (379,)
# (788,)
# prueba = 35.35958904109589
# (417,)
# (400,)
# (896,)
# (623,)
# validación = 52.78253424657534
# (436,)
# (361,)
# (888,)
# (651,)
# prueba = 53.296232876712324
# (626,)
# (527,)
# (616,)
# (567,)
# validación = 68.10787671232876
# (630,)
# (511,)
# (591,)
# (604,)
# prueba = 70.11986301369863
# (638,)
# (544,)
# (586,)
# (568,)
# validación = 71.4041095890411
# (598,)
# (536,)
# (603,)
# (599,)
# prueba = 68.66438356164383
# (732,)
# (657,)
# (341,)
# (606,)
# validación = 34.50342465753425
# (714,)
# (661,)
# (353,)
# (608,)
# prueba = 35.44520547945205
# (491,)
# (469,)
# (672,)
# (704,)
# validación = 48.67294520547945
# (482,)
# (461,)
# (654,)
# (739,)
# prueba = 49.571917808219176
# (596,)
# (548,)
# (637,)
# (555,)
# validación = 69.82020547945206
# (633,)
# (517,)
# (589,)
# (597,)
# prueba = 71.875
# (640,)
# (547,)
# (587,)
# (562,)
# validación = 69.64897260273972
# (625,)
# (516,)
# (596,)
# (599,)
# prueba = 69.17808219178082
# (385,)
# (247,)
# (888,)
# (816,)
# validación = 30.179794520547947
# (397,)
# (282,)
# (856,)
# (801,)
# prueba = 31.29280821917808
# (353,)
# (939,)
# (394,)
# (650,)
# validación = 48.03082191780822
# (348,)
# (925,)
# (369,)
# (694,)
# prueba = 45.80479452054795
# (634,)
# (513,)
# (592,)
# (597,)
# validación = 68.87842465753424
# (617,)
# (478,)
# (637,)
# (604,)
# prueba = 69.56335616438356
# (624,)
# (549,)
# (607,)
# (556,)
# validación = 71.66095890410958
# (629,)
# (534,)
# (583,)
# (590,)
# prueba = 71.70376712328768
# (686,)
# (517,)
# (601,)
# (532,)
# validación = 33.6472602739726
# (691,)
# (504,)
# (586,)
# (555,)
# prueba = 33.21917808219178
# (767,)
# (399,)
# (506,)
# (664,)
# validación = 54.0667808219178
# (704,)
# (385,)
# (571,)
# (676,)
# prueba = 54.70890410958904
# (724,)
# (494,)
# (537,)
# (581,)
# validación = 60.70205479452054
# (616,)
# (527,)
# (562,)
# (631,)
# prueba = 62.328767123287676
# (705,)
# (474,)
# (554,)
# (603,)
# validación = 61.5582191780822
# (709,)
# (437,)
# (551,)
# (639,)
# prueba = 61.5582191780822
# (580,)
# (481,)
# (86,)
# (1189,)
# validación = 27.61130136986301
# (591,)
# (423,)
# (81,)
# (1241,)
# prueba = 31.335616438356162
# (819,)
# (413,)
# (408,)
# (696,)
# validación = 42.03767123287671
# (837,)
# (366,)
# (407,)
# (726,)
# prueba = 42.67979452054795
# (859,)
# (247,)
# (605,)
# (625,)
# validación = 51.49828767123288
# (855,)
# (246,)
# (596,)
# (639,)
# prueba = 55.00856164383562
# (995,)
# (489,)
# (239,)
# (613,)
# validación = 50.12842465753424
# (969,)
# (522,)
# (225,)
# (620,)
# prueba = 51.02739726027398
# (485,)
# (168,)
# (831,)
# (852,)
# validación = 31.506849315068493
# (441,)
# (166,)
# (832,)
# (897,)
# prueba = 31.035958904109588
# (684,)
# (338,)
# (608,)
# (706,)
# validación = 57.40582191780822
# (667,)
# (359,)
# (567,)
# (743,)
# prueba = 57.87671232876712
# (611,)
# (548,)
# (617,)
# (560,)
# validación = 72.47431506849315
# (595,)
# (538,)
# (597,)
# (606,)
# prueba = 73.58732876712328
# (610,)
# (524,)
# (633,)
# (569,)
# validación = 70.63356164383562
# (610,)
# (563,)
# (566,)
# (597,)
# prueba = 69.77739726027397
# (608,)
# (933,)
# (170,)
# (625,)
# validación = 29.45205479452055
# (620,)
# (918,)
# (211,)
# (587,)
# prueba = 30.30821917808219
# (645,)
# (285,)
# (765,)
# (641,)
# validación = 56.849315068493155
# (639,)
# (301,)
# (724,)
# (672,)
# prueba = 60.05993150684932
# (595,)
# (580,)
# (611,)
# (550,)
# validación = 68.40753424657534
# (564,)
# (530,)
# (641,)
# (601,)
# prueba = 71.01883561643835
# (606,)
# (584,)
# (595,)
# (551,)
# validación = 67.63698630136986
# (591,)
# (555,)
# (632,)
# (558,)
# prueba = 69.9486301369863
# (638,)
# (516,)
# (556,)
# (626,)
# validación = 30.82191780821918
# (622,)
# (518,)
# (534,)
# (662,)
# prueba = 31.7208904109589
# (661,)
# (700,)
# (305,)
# (670,)
# validación = 51.24143835616438
# (671,)
# (658,)
# (305,)
# (702,)
# prueba = 53.296232876712324
# (629,)
# (555,)
# (580,)
# (572,)
# validación = 71.23287671232876
# (651,)
# (532,)
# (560,)
# (593,)
# prueba = 70.4195205479452
# (611,)
# (557,)
# (615,)
# (553,)
# validación = 69.6917808219178
# (603,)
# (537,)
# (591,)
# (605,)
# prueba = 70.50513698630137
# (657,)
# (703,)
# (185,)
# (791,)
# validación = 29.45205479452055
# (616,)
# (738,)
# (194,)
# (788,)
# prueba = 30.607876712328768
# (689,)
# (573,)
# (423,)
# (651,)
# validación = 51.369863013698634
# (596,)
# (586,)
# (476,)
# (678,)
# prueba = 53.21061643835616
# (660,)
# (484,)
# (612,)
# (580,)
# validación = 68.4931506849315
# (654,)
# (457,)
# (616,)
# (609,)
# prueba = 69.9486301369863
# (637,)
# (545,)
# (603,)
# (551,)
# validación = 67.42294520547945
# (610,)
# (525,)
# (605,)
# (596,)
# prueba = 68.87842465753424
# (825,)
# (393,)
# (426,)
# (692,)
# validación = 29.3236301369863
# (745,)
# (395,)
# (447,)
# (749,)
# prueba = 31.035958904109588
# (648,)
# (499,)
# (523,)
# (666,)
# validación = 53.125
# (630,)
# (502,)
# (507,)
# (697,)
# prueba = 54.83732876712328
# (619,)
# (552,)
# (591,)
# (574,)
# validación = 70.29109589041096
# (613,)
# (524,)
# (595,)
# (604,)
# prueba = 70.50513698630137
# (631,)
# (517,)
# (617,)
# (571,)
# validación = 68.96404109589042
# (629,)
# (493,)
# (601,)
# (613,)
# prueba = 70.11986301369863
# (522,)
# (616,)
# (460,)
# (738,)
# validación = 32.06335616438356
# (515,)
# (579,)
# (504,)
# (738,)
# prueba = 34.375
# (603,)
# (366,)
# (637,)
# (730,)
# validación = 55.821917808219176
# (598,)
# (341,)
# (641,)
# (756,)
# prueba = 58.775684931506845
# (609,)
# (542,)
# (595,)
# (590,)
# validación = 71.4041095890411
# (621,)
# (493,)
# (609,)
# (613,)
# prueba = 71.57534246575342
# (626,)
# (540,)
# (589,)
# (581,)
# validación = 69.39212328767124
# (605,)
# (510,)
# (626,)
# (595,)
# prueba = 68.53595890410958
# (620,)
# (532,)
# (474,)
# (710,)
# validación = 31.464041095890412
# (656,)
# (481,)
# (507,)
# (692,)
# prueba = 33.090753424657535
# (676,)
# (299,)
# (700,)
# (661,)
# validación = 54.880136986301366
# (613,)
# (306,)
# (729,)
# (688,)
# prueba = 57.40582191780822
# (619,)
# (532,)
# (612,)
# (573,)
# validación = 70.11986301369863
# (603,)
# (508,)
# (619,)
# (606,)
# prueba = 70.24828767123287
# (608,)
# (553,)
# (601,)
# (574,)
# validación = 71.44691780821918
# (601,)
# (479,)
# (616,)
# (640,)
# prueba = 72.94520547945206
# (777,)
# (634,)
# (302,)
# (623,)
# validación = 28.29623287671233
# (770,)
# (596,)
# (324,)
# (646,)
# prueba = 29.83732876712329
# (670,)
# (725,)
# (317,)
# (624,)
# validación = 42.97945205479452
# (623,)
# (680,)
# (372,)
# (661,)
# prueba = 46.61815068493151
# (746,)
# (373,)
# (618,)
# (599,)
# validación = 60.830479452054796
# (752,)
# (327,)
# (630,)
# (627,)
# prueba = 61.94349315068494
# (740,)
# (479,)
# (543,)
# (574,)
# validación = 65.79623287671232
# (722,)
# (445,)
# (537,)
# (632,)
# prueba = 65.75342465753424
# (147,)
# (591,)
# (494,)
# (1104,)
# validación = 28.424657534246577
# (152,)
# (569,)
# (486,)
# (1129,)
# prueba = 30.69349315068493
# (743,)
# (164,)
# (486,)
# (943,)
# validación = 37.15753424657534
# (690,)
# (173,)
# (537,)
# (936,)
# prueba = 39.21232876712329
# (834,)
# (229,)
# (677,)
# (596,)
# validación = 53.03938356164384
# (894,)
# (197,)
# (640,)
# (605,)
# prueba = 53.93835616438356
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# (883,)
# (597,)
# (206,)
# (650,)
# validación = 51.02739726027398
# (891,)
# (576,)
# (213,)
# (656,)
# prueba = 52.140410958904106
# (582,)
# (302,)
# (781,)
# (671,)
# validación = 35.53082191780822
# (638,)
# (312,)
# (737,)
# (649,)
# prueba = 37.41438356164384
# (735,)
# (401,)
# (515,)
# (685,)
# validación = 52.26883561643836
# (679,)
# (416,)
# (539,)
# (702,)
# prueba = 53.339041095890416
# (670,)
# (484,)
# (614,)
# (568,)
# validación = 68.83561643835617
# (650,)
# (463,)
# (623,)
# (600,)
# prueba = 70.37671232876713
# (622,)
# (560,)
# (577,)
# (577,)
# validación = 65.28253424657534
# (616,)
# (551,)
# (574,)
# (595,)
# prueba = 66.86643835616438
# (729,)
# (443,)
# (292,)
# (872,)
# validación = 27.69691780821918
# (744,)
# (437,)
# (281,)
# (874,)
# prueba = 28.767123287671232
# (835,)
# (272,)
# (588,)
# (641,)
# validación = 53.3818493150685
# (847,)
# (226,)
# (593,)
# (670,)
# prueba = 54.494863013698634
# (639,)
# (559,)
# (563,)
# (575,)
# validación = 68.57876712328768
# (608,)
# (508,)
# (593,)
# (627,)
# prueba = 69.60616438356165
# (636,)
# (544,)
# (562,)
# (594,)
# validación = 69.26369863013699
# (604,)
# (503,)
# (624,)
# (605,)
# prueba = 68.40753424657534
# (592,)
# (742,)
# (329,)
# (673,)
# validación = 30.65068493150685
# (600,)
# (709,)
# (337,)
# (690,)
# prueba = 30.43664383561644
# (718,)
# (483,)
# (520,)
# (615,)
# validación = 52.73972602739726
# (638,)
# (517,)
# (522,)
# (659,)
# prueba = 54.45205479452054
# (629,)
# (573,)
# (546,)
# (588,)
# validación = 70.9332191780822
# (614,)
# (545,)
# (569,)
# (608,)
# prueba = 66.6095890410959
# (618,)
# (554,)
# (592,)
# (572,)
# validación = 67.72260273972603
# (613,)
# (518,)
# (597,)
# (608,)
# prueba = 69.90582191780823
# (230,)
# (784,)
# (488,)
# (834,)
# validación = 28.72431506849315
# (229,)
# (741,)
# (531,)
# (835,)
# prueba = 29.36643835616438
# (684,)
# (361,)
# (611,)
# (680,)
# validación = 51.79794520547946
# (706,)
# (345,)
# (576,)
# (709,)
# prueba = 52.611301369863014
# (652,)
# (529,)
# (586,)
# (569,)
# validación = 70.59075342465754
# (606,)
# (518,)
# (619,)
# (593,)
# prueba = 71.36130136986301
# (634,)
# (540,)
# (566,)
# (596,)
# validación = 67.97945205479452
# (593,)
# (547,)
# (588,)
# (608,)
# prueba = 68.70719178082192
# (740,)
# (336,)
# (818,)
# (442,)
# validación = 30.43664383561644
# (771,)
# (344,)
# (760,)
# (461,)
# prueba = 31.035958904109588
# (591,)
# (469,)
# (618,)
# (658,)
# validación = 50.9417808219178
# (586,)
# (396,)
# (611,)
# (743,)
# prueba = 51.070205479452056
# (614,)
# (573,)
# (578,)
# (571,)
# validación = 67.89383561643835
# (629,)
# (507,)
# (584,)
# (616,)
# prueba = 70.16267123287672
# (621,)
# (529,)
# (606,)
# (580,)
# validación = 69.52054794520548
# (607,)
# (511,)
# (611,)
# (607,)
# prueba = 68.79280821917808
# (533,)
# (502,)
# (458,)
# (843,)
# validación = 28.039383561643838
# (521,)
# (458,)
# (497,)
# (860,)
# prueba = 30.565068493150683
# (604,)
# (413,)
# (618,)
# (701,)
# validación = 52.6541095890411
# (577,)
# (403,)
# (627,)
# (729,)
# prueba = 52.525684931506845
# (656,)
# (491,)
# (613,)
# (576,)
# validación = 67.89383561643835
# (631,)
# (491,)
# (607,)
# (607,)
# prueba = 68.96404109589042
# (633,)
# (522,)
# (593,)
# (588,)
# validación = 71.70376712328768
# (597,)
# (524,)
# (616,)
# (599,)
# prueba = 70.76198630136986
# (225,)
# (506,)
# (662,)
# (943,)
# validación = 25.17123287671233
# (233,)
# (466,)
# (655,)
# (982,)
# prueba = 27.097602739726028
# (711,)
# (537,)
# (582,)
# (506,)
# validación = 31.07876712328767
# (664,)
# (523,)
# (603,)
# (546,)
# prueba = 28.852739726027398
# (625,)
# (573,)
# (545,)
# (593,)
# validación = 65.66780821917808
# (619,)
# (497,)
# (586,)
# (634,)
# prueba = 68.79280821917808
# (677,)
# (532,)
# (569,)
# (558,)
# validación = 65.8818493150685
# (638,)
# (523,)
# (568,)
# (607,)
# prueba = 68.57876712328768
# (566,)
# (593,)
# (720,)
# (457,)
# validación = 31.84931506849315
# (514,)
# (635,)
# (723,)
# (464,)
# prueba = 31.80650684931507
# (926,)
# (322,)
# (429,)
# (659,)
# validación = 44.39212328767123
# (917,)
# (361,)
# (379,)
# (679,)
# prueba = 44.73458904109589
# (765,)
# (383,)
# (570,)
# (618,)
# validación = 57.87671232876712
# (730,)
# (383,)
# (552,)
# (671,)
# prueba = 58.26198630136986
# (682,)
# (429,)
# (631,)
# (594,)
# validación = 66.22431506849315
# (677,)
# (393,)
# (640,)
# (626,)
# prueba = 65.45376712328768
# (697,)
# (694,)
# (515,)
# (430,)
# validación = 29.83732876712329
# (652,)
# (679,)
# (540,)
# (465,)
# prueba = 26.583904109589042
# (418,)
# (218,)
# (1056,)
# (644,)
# validación = 44.77739726027397
# (365,)
# (235,)
# (1038,)
# (698,)
# prueba = 44.9486301369863
# (831,)
# (166,)
# (639,)
# (700,)
# validación = 49.2722602739726
# (762,)
# (197,)
# (654,)
# (723,)
# prueba = 51.15582191780822
# (786,)
# (252,)
# (698,)
# (600,)
# validación = 51.62671232876712
# (798,)
# (218,)
# (655,)
# (665,)
# prueba = 52.953767123287676
# (769,)
# (635,)
# (390,)
# (542,)
# validación = 29.708904109589042
# (742,)
# (660,)
# (352,)
# (582,)
# prueba = 30.26541095890411
# (536,)
# (442,)
# (696,)
# (662,)
# validación = 48.84417808219178
# (564,)
# (397,)
# (672,)
# (703,)
# prueba = 49.14383561643836
# (629,)
# (507,)
# (639,)
# (561,)
# validación = 68.06506849315068
# (623,)
# (494,)
# (629,)
# (590,)
# prueba = 67.67979452054794
# (621,)
# (556,)
# (578,)
# (581,)
# validación = 60.40239726027398
# (595,)
# (558,)
# (582,)
# (601,)
# prueba = 62.37157534246576
# (611,)
# (508,)
# (434,)
# (783,)
# validación = 28.72431506849315
# (622,)
# (506,)
# (476,)
# (732,)
# prueba = 29.238013698630137
# (781,)
# (349,)
# (565,)
# (641,)
# validación = 48.33047945205479
# (753,)
# (352,)
# (582,)
# (649,)
# prueba = 48.0736301369863
# (611,)
# (530,)
# (614,)
# (581,)
# validación = 67.67979452054794
# (614,)
# (504,)
# (615,)
# (603,)
# prueba = 69.43493150684932
# (615,)
# (542,)
# (598,)
# (581,)
# validación = 66.48116438356165
# (574,)
# (541,)
# (637,)
# (584,)
# prueba = 65.3681506849315
# (943,)
# (214,)
# (412,)
# (767,)
# validación = 30.26541095890411
# (939,)
# (181,)
# (408,)
# (808,)
# prueba = 31.59246575342466
# (694,)
# (278,)
# (725,)
# (639,)
# validación = 46.27568493150685
# (729,)
# (248,)
# (682,)
# (677,)
# prueba = 47.26027397260274
# (629,)
# (534,)
# (593,)
# (580,)
# validación = 67.25171232876713
# (606,)
# (471,)
# (650,)
# (609,)
# prueba = 67.5513698630137
# (629,)
# (529,)
# (600,)
# (578,)
# validación = 65.96746575342466
# (592,)
# (503,)
# (606,)
# (635,)
# prueba = 67.5513698630137
# (327,)
# (581,)
# (671,)
# (757,)
# validación = 34.375
# (334,)
# (577,)
# (718,)
# (707,)
# prueba = 36.17294520547945
# (726,)
# (437,)
# (523,)
# (650,)
# validación = 51.840753424657535
# (691,)
# (485,)
# (509,)
# (651,)
# prueba = 54.28082191780822
# (658,)
# (519,)
# (566,)
# (593,)
# validación = 64.6832191780822
# (644,)
# (485,)
# (584,)
# (623,)
# prueba = 66.48116438356165
# (635,)
# (546,)
# (604,)
# (551,)
# validación = 65.83904109589042
# (620,)
# (513,)
# (597,)
# (606,)
# prueba = 66.48116438356165
# (474,)
# (358,)
# (581,)
# (923,)
# validación = 29.53767123287671
# (496,)
# (343,)
# (605,)
# (892,)
# prueba = 28.89554794520548
# (723,)
# (451,)
# (467,)
# (695,)
# validación = 51.369863013698634
# (710,)
# (426,)
# (475,)
# (725,)
# prueba = 50.171232876712324
# (617,)
# (523,)
# (629,)
# (567,)
# validación = 65.8818493150685
# (625,)
# (480,)
# (610,)
# (621,)
# prueba = 67.5513698630137
# (658,)
# (512,)
# (585,)
# (581,)
# validación = 67.12328767123287
# (616,)
# (497,)
# (603,)
# (620,)
# prueba = 67.63698630136986
# (638,)
# (938,)
# (181,)
# (579,)
# validación = 30.26541095890411
# (623,)
# (926,)
# (194,)
# (593,)
# prueba = 30.26541095890411
# (633,)
# (390,)
# (623,)
# (690,)
# validación = 51.15582191780822
# (570,)
# (406,)
# (652,)
# (708,)
# prueba = 52.99657534246576
# (618,)
# (530,)
# (606,)
# (582,)
# validación = 67.93664383561644
# (605,)
# (534,)
# (573,)
# (624,)
# prueba = 68.15068493150685
# (630,)
# (506,)
# (608,)
# (592,)
# validación = 69.26369863013699
# (668,)
# (441,)
# (614,)
# (613,)
# prueba = 69.56335616438356
# (732,)
# (184,)
# (849,)
# (571,)
# validación = 28.89554794520548
# (693,)
# (191,)
# (868,)
# (584,)
# prueba = 31.29280821917808
# (864,)
# (268,)
# (613,)
# (591,)
# validación = 46.06164383561644
# (857,)
# (226,)
# (607,)
# (646,)
# prueba = 48.75856164383562
# (618,)
# (506,)
# (603,)
# (609,)
# validación = 64.34075342465754
# (625,)
# (500,)
# (591,)
# (620,)
# prueba = 65.625
# (635,)
# (522,)
# (598,)
# (581,)
# validación = 65.96746575342466
# (641,)
# (472,)
# (599,)
# (624,)
# prueba = 68.32191780821918
# (790,)
# (596,)
# (468,)
# (482,)
# validación = 29.62328767123288
# (789,)
# (589,)
# (437,)
# (521,)
# prueba = 28.339041095890412
# (715,)
# (450,)
# (462,)
# (709,)
# validación = 49.78595890410959
# (718,)
# (425,)
# (473,)
# (720,)
# prueba = 50.9417808219178
# (714,)
# (458,)
# (588,)
# (576,)
# validación = 62.58561643835616
# (706,)
# (450,)
# (570,)
# (610,)
# prueba = 62.5
# (691,)
# (492,)
# (552,)
# (601,)
# validación = 59.46061643835616
# (703,)
# (428,)
# (574,)
# (631,)
# prueba = 59.6318493150685
# (873,)
# (531,)
# (316,)
# (616,)
# validación = 38.61301369863014
# (904,)
# (516,)
# (293,)
# (623,)
# prueba = 36.81506849315068
# (862,)
# (263,)
# (429,)
# (782,)
# validación = 45.63356164383562
# (901,)
# (260,)
# (405,)
# (770,)
# prueba = 45.84760273972603
# (478,)
# (529,)
# (662,)
# (667,)
# validación = 46.48972602739726
# (423,)
# (495,)
# (684,)
# (734,)
# prueba = 48.33047945205479
# (863,)
# (222,)
# (611,)
# (640,)
# validación = 53.03938356164384
# (880,)
# (210,)
# (595,)
# (651,)
# prueba = 51.369863013698634
# (491,)
# (446,)
# (577,)
# (822,)
# validación = 28.339041095890412
# (474,)
# (395,)
# (580,)
# (887,)
# prueba = 29.92294520547945
# (394,)
# (693,)
# (552,)
# (697,)
# validación = 45.24828767123288
# (378,)
# (661,)
# (564,)
# (733,)
# prueba = 46.832191780821915
# (596,)
# (565,)
# (587,)
# (588,)
# validación = 63.099315068493155
# (578,)
# (542,)
# (569,)
# (647,)
# prueba = 65.8818493150685
# (619,)
# (521,)
# (618,)
# (578,)
# validación = 63.869863013698634
# (571,)
# (547,)
# (599,)
# (619,)
# prueba = 64.59760273972603
# (585,)
# (314,)
# (476,)
# (961,)
# validación = 27.910958904109588
# (629,)
# (275,)
# (456,)
# (976,)
# prueba = 29.92294520547945
# (587,)
# (464,)
# (554,)
# (731,)
# validación = 50.38527397260274
# (588,)
# (448,)
# (536,)
# (764,)
# prueba = 51.369863013698634
# (687,)
# (512,)
# (552,)
# (585,)
# validación = 66.5667808219178
# (636,)
# (479,)
# (584,)
# (637,)
# prueba = 66.8236301369863
# (634,)
# (562,)
# (561,)
# (579,)
# validación = 64.38356164383562
# (598,)
# (511,)
# (620,)
# (607,)
# prueba = 62.62842465753424
# (669,)
# (430,)
# (386,)
# (851,)
# validación = 27.14041095890411
# (675,)
# (444,)
# (430,)
# (787,)
# prueba = 29.238013698630137
# (673,)
# (397,)
# (608,)
# (658,)
# validación = 49.82876712328767
# (635,)
# (419,)
# (593,)
# (689,)
# prueba = 51.669520547945204
# (601,)
# (526,)
# (632,)
# (577,)
# validación = 63.74143835616438
# (591,)
# (500,)
# (611,)
# (634,)
# prueba = 64.38356164383562
# (634,)
# (548,)
# (589,)
# (565,)
# validación = 64.76883561643835
# (611,)
# (487,)
# (616,)
# (622,)
# prueba = 63.99828767123288
# (467,)
# (571,)
# (590,)
# (708,)
# validación = 30.179794520547947
# (502,)
# (566,)
# (572,)
# (696,)
# prueba = 29.88013698630137
# (746,)
# (348,)
# (480,)
# (762,)
# validación = 47.3458904109589
# (731,)
# (312,)
# (514,)
# (779,)
# prueba = 50.81335616438356
# (620,)
# (519,)
# (593,)
# (604,)
# validación = 63.869863013698634
# (632,)
# (466,)
# (598,)
# (640,)
# prueba = 64.04109589041096
# (638,)
# (480,)
# (618,)
# (600,)
# validación = 63.99828767123288
# (613,)
# (495,)
# (620,)
# (608,)
# prueba = 64.38356164383562
# (1144,)
# (556,)
# (268,)
# (368,)
# validación = 32.57705479452055
# (1141,)
# (534,)
# (267,)
# (394,)
# prueba = 31.7208904109589
# (769,)
# (418,)
# (325,)
# (824,)
# validación = 42.08047945205479
# (800,)
# (393,)
# (317,)
# (826,)
# prueba = 42.93664383561644
# (629,)
# (485,)
# (624,)
# (598,)
# validación = 64.38356164383562
# (620,)
# (512,)
# (598,)
# (606,)
# prueba = 64.08390410958904
# (630,)
# (509,)
# (604,)
# (593,)
# validación = 65.625
# (617,)
# (481,)
# (615,)
# (623,)
# prueba = 65.83904109589042
# (594,)
# (582,)
# (388,)
# (772,)
# validación = 29.10958904109589
# (556,)
# (542,)
# (420,)
# (818,)
# prueba = 27.910958904109588
# (638,)
# (305,)
# (700,)
# (693,)
# validación = 49.18664383561644
# (637,)
# (314,)
# (688,)
# (697,)
# prueba = 47.98801369863014
# (683,)
# (469,)
# (597,)
# (587,)
# validación = 63.14212328767124
# (690,)
# (457,)
# (570,)
# (619,)
# prueba = 61.7722602739726
# (654,)
# (501,)
# (595,)
# (586,)
# validación = 65.79623287671232
# (615,)
# (442,)
# (651,)
# (628,)
# prueba = 66.18150684931507
# (939,)
# (421,)
# (499,)
# (477,)
# validación = 31.464041095890412
# (883,)
# (448,)
# (460,)
# (545,)
# prueba = 33.81849315068493
# (781,)
# (629,)
# (295,)
# (631,)
# validación = 49.5291095890411
# (806,)
# (524,)
# (312,)
# (694,)
# prueba = 49.2722602739726
# (616,)
# (499,)
# (604,)
# (617,)
# validación = 61.515410958904106
# (626,)
# (497,)
# (574,)
# (639,)
# prueba = 62.457191780821915
# (648,)
# (533,)
# (556,)
# (599,)
# validación = 64.12671232876713
# (645,)
# (474,)
# (584,)
# (633,)
# prueba = 66.0958904109589
# (693,)
# (336,)
# (239,)
# (1068,)
# validación = 27.825342465753423
# (690,)
# (326,)
# (271,)
# (1049,)
# prueba = 29.28082191780822
# (778,)
# (434,)
# (429,)
# (695,)
# validación = 48.58732876712329
# (738,)
# (453,)
# (426,)
# (719,)
# prueba = 48.63013698630137
# (684,)
# (478,)
# (569,)
# (605,)
# validación = 56.63527397260274
# (675,)
# (476,)
# (556,)
# (629,)
# prueba = 58.304794520547944
# (723,)
# (520,)
# (489,)
# (604,)
# validación = 55.56506849315068
# (710,)
# (466,)
# (504,)
# (656,)
# prueba = 55.13698630136986
# (852,)
# (285,)
# (519,)
# (680,)
# validación = 28.72431506849315
# (805,)
# (318,)
# (517,)
# (696,)
# prueba = 30.00856164383562
# (441,)
# (601,)
# (610,)
# (684,)
# validación = 32.148972602739725
# (437,)
# (587,)
# (639,)
# (673,)
# prueba = 34.20376712328767
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# (1011,)
# (407,)
# (269,)
# (649,)
# validación = 49.91438356164384
# (994,)
# (391,)
# (261,)
# (690,)
# prueba = 51.32705479452054
# (754,)
# (302,)
# (596,)
# (684,)
# validación = 50.599315068493155
# (788,)
# (277,)
# (597,)
# (674,)
# prueba = 49.5291095890411
# (986,)
# (641,)
# (19,)
# (690,)
# validación = 28.125
# (970,)
# (601,)
# (16,)
# (749,)
# prueba = 28.98116438356164
# (880,)
# (493,)
# (316,)
# (647,)
# validación = 26.24143835616438
# (882,)
# (457,)
# (320,)
# (677,)
# prueba = 27.097602739726028
# (635,)
# (494,)
# (600,)
# (607,)
# validación = 60.05993150684932
# (621,)
# (436,)
# (629,)
# (650,)
# prueba = 61.64383561643836
# (685,)
# (469,)
# (574,)
# (608,)
# validación = 57.49143835616438
# (617,)
# (466,)
# (622,)
# (631,)
# prueba = 57.919520547945204
# (938,)
# (509,)
# (124,)
# (765,)
# validación = 26.62671232876712
# (911,)
# (520,)
# (127,)
# (778,)
# prueba = 27.95376712328767
# (574,)
# (439,)
# (531,)
# (792,)
# validación = 47.388698630136986
# (604,)
# (401,)
# (539,)
# (792,)
# prueba = 46.53253424657534
# (625,)
# (510,)
# (607,)
# (594,)
# validación = 55.00856164383562
# (644,)
# (489,)
# (614,)
# (589,)
# prueba = 56.292808219178085
# (609,)
# (508,)
# (597,)
# (622,)
# validación = 58.476027397260275
# (606,)
# (482,)
# (617,)
# (631,)
# prueba = 58.73287671232876
# (600,)
# (494,)
# (442,)
# (800,)
# validación = 28.339041095890412
# (607,)
# (455,)
# (472,)
# (802,)
# prueba = 28.852739726027398
# (523,)
# (449,)
# (570,)
# (794,)
# validación = 47.68835616438356
# (541,)
# (431,)
# (593,)
# (771,)
# prueba = 46.4041095890411
# (668,)
# (452,)
# (604,)
# (612,)
# validación = 58.861301369863014
# (633,)
# (443,)
# (610,)
# (650,)
# prueba = 59.375
# (640,)
# (449,)
# (622,)
# (625,)
# validación = 56.292808219178085
# (636,)
# (464,)
# (622,)
# (614,)
# prueba = 57.148972602739725
# (488,)
# (658,)
# (624,)
# (566,)
# validación = 28.46746575342466
# (512,)
# (641,)
# (625,)
# (558,)
# prueba = 27.22602739726027
# (832,)
# (329,)
# (533,)
# (642,)
# validación = 50.898972602739725
# (845,)
# (326,)
# (481,)
# (684,)
# prueba = 51.755136986301366
# (667,)
# (426,)
# (588,)
# (655,)
# validación = 55.0513698630137
# (648,)
# (444,)
# (577,)
# (667,)
# prueba = 56.464041095890416
# (623,)
# (486,)
# (628,)
# (599,)
# validación = 58.946917808219176
# (614,)
# (488,)
# (592,)
# (642,)
# prueba = 59.203767123287676
# (324,)
# (281,)
# (595,)
# (1136,)
# validación = 25.4708904109589
# (352,)
# (250,)
# (622,)
# (1112,)
# prueba = 26.9263698630137
# (457,)
# (457,)
# (559,)
# (863,)
# validación = 42.20890410958904
# (417,)
# (399,)
# (624,)
# (896,)
# prueba = 44.04965753424658
# (673,)
# (469,)
# (561,)
# (633,)
# validación = 57.83390410958904
# (637,)
# (476,)
# (567,)
# (656,)
# prueba = 59.76027397260274
# (675,)
# (514,)
# (569,)
# (578,)
# validación = 61.72945205479452
# (655,)
# (448,)
# (601,)
# (632,)
# prueba = 62.2431506849315
# (396,)
# (486,)
# (784,)
# (670,)
# validación = 28.25342465753425
# (418,)
# (445,)
# (823,)
# (650,)
# prueba = 31.76369863013699
# (545,)
# (554,)
# (504,)
# (733,)
# validación = 43.707191780821915
# (565,)
# (521,)
# (470,)
# (780,)
# prueba = 45.50513698630137
# (621,)
# (511,)
# (620,)
# (584,)
# validación = 59.03253424657534
# (599,)
# (476,)
# (617,)
# (644,)
# prueba = 60.3167808219178
# (670,)
# (503,)
# (569,)
# (594,)
# validación = 60.18835616438356
# (658,)
# (478,)
# (580,)
# (620,)
# prueba = 61.94349315068494
# (731,)
# (501,)
# (304,)
# (800,)
# validación = 27.097602739726028
# (742,)
# (450,)
# (338,)
# (806,)
# prueba = 27.31164383561644
# (242,)
# (569,)
# (709,)
# (816,)
# validación = 42.20890410958904
# (216,)
# (596,)
# (713,)
# (811,)
# prueba = 42.465753424657535
# (701,)
# (398,)
# (582,)
# (655,)
# validación = 55.3082191780822
# (676,)
# (381,)
# (588,)
# (691,)
# prueba = 55.265410958904106
# (673,)
# (481,)
# (566,)
# (616,)
# validación = 55.86472602739726
# (684,)
# (429,)
# (578,)
# (645,)
# prueba = 61.3013698630137
# (611,)
# (513,)
# (360,)
# (852,)
# validación = 25.59931506849315
# (562,)
# (557,)
# (419,)
# (798,)
# prueba = 29.580479452054792
# (625,)
# (376,)
# (732,)
# (603,)
# validación = 42.42294520547945
# (633,)
# (367,)
# (754,)
# (582,)
# prueba = 44.90582191780822
# (707,)
# (380,)
# (603,)
# (646,)
# validación = 56.54965753424658
# (663,)
# (395,)
# (593,)
# (685,)
# prueba = 56.849315068493155
# (694,)
# (449,)
# (562,)
# (631,)
# validación = 53.42465753424658
# (673,)
# (429,)
# (592,)
# (642,)
# prueba = 57.534246575342465
# (857,)
# (890,)
# (14,)
# (575,)
# validación = 27.482876712328768
# (837,)
# (875,)
# (15,)
# (609,)
# prueba = 28.93835616438356
# (887,)
# (374,)
# (665,)
# (410,)
# validación = 26.79794520547945
# (885,)
# (331,)
# (682,)
# (438,)
# prueba = 28.039383561643838
# (1017,)
# (158,)
# (486,)
# (675,)
# validación = 44.77739726027397
# (991,)
# (132,)
# (487,)
# (726,)
# prueba = 45.76198630136986
# (781,)
# (162,)
# (694,)
# (699,)
# validación = 46.31849315068493
# (772,)
# (183,)
# (658,)
# (723,)
# prueba = 47.17465753424658
# (624,)
# (635,)
# (356,)
# (721,)
# validación = 25.85616438356164
# (636,)
# (611,)
# (349,)
# (740,)
# prueba = 27.440068493150683
# (581,)
# (314,)
# (601,)
# (840,)
# validación = 42.29452054794521
# (564,)
# (270,)
# (599,)
# (903,)
# prueba = 41.48116438356164
# (669,)
# (420,)
# (583,)
# (664,)
# validación = 52.226027397260275
# (686,)
# (417,)
# (569,)
# (664,)
# prueba = 52.26883561643836
# (659,)
# (513,)
# (559,)
# (605,)
# validación = 51.24143835616438
# (683,)
# (468,)
# (537,)
# (648,)
# prueba = 52.054794520547944
# (715,)
# (340,)
# (455,)
# (826,)
# validación = 27.011986301369863
# (717,)
# (288,)
# (543,)
# (788,)
# prueba = 29.195205479452053
# (744,)
# (388,)
# (395,)
# (809,)
# validación = 37.20034246575342
# (721,)
# (411,)
# (379,)
# (825,)
# prueba = 36.51541095890411
# (623,)
# (446,)
# (646,)
# (621,)
# validación = 52.44006849315068
# (618,)
# (477,)
# (612,)
# (629,)
# prueba = 52.226027397260275
# (662,)
# (443,)
# (566,)
# (665,)
# validación = 51.62671232876712
# (652,)
# (413,)
# (616,)
# (655,)
# prueba = 51.840753424657535
# (837,)
# (697,)
# (43,)
# (759,)
# validación = 24.95719178082192
# (847,)
# (664,)
# (46,)
# (779,)
# prueba = 25.81335616438356
# (476,)
# (190,)
# (555,)
# (1115,)
# validación = 34.76027397260274
# (473,)
# (173,)
# (591,)
# (1099,)
# prueba = 34.803082191780824
# (667,)
# (433,)
# (602,)
# (634,)
# validación = 52.6541095890411
# (683,)
# (373,)
# (616,)
# (664,)
# prueba = 53.80993150684932
# (672,)
# (433,)
# (617,)
# (614,)
# validación = 51.62671232876712
# (609,)
# (455,)
# (620,)
# (652,)
# prueba = 52.525684931506845
# (764,)
# (417,)
# (311,)
# (844,)
# validación = 27.054794520547947
# (691,)
# (446,)
# (294,)
# (905,)
# prueba = 27.78253424657534
# (476,)
# (662,)
# (533,)
# (665,)
# validación = 35.53082191780822
# (471,)
# (649,)
# (546,)
# (670,)
# prueba = 37.79965753424658
# (641,)
# (509,)
# (561,)
# (625,)
# validación = 48.0736301369863
# (626,)
# (449,)
# (592,)
# (669,)
# prueba = 49.5291095890411
# (678,)
# (467,)
# (556,)
# (635,)
# validación = 52.44006849315068
# (663,)
# (451,)
# (568,)
# (654,)
# prueba = 53.553082191780824
# (561,)
# (606,)
# (330,)
# (839,)
# validación = 31.506849315068493
# (556,)
# (579,)
# (357,)
# (844,)
# prueba = 30.73630136986301
# (504,)
# (245,)
# (778,)
# (809,)
# validación = 41.138698630136986
# (506,)
# (243,)
# (803,)
# (784,)
# prueba = 44.13527397260274
# (683,)
# (477,)
# (542,)
# (634,)
# validación = 50.4708904109589
# (699,)
# (422,)
# (571,)
# (644,)
# prueba = 52.31164383561644
# (655,)
# (435,)
# (605,)
# (641,)
# validación = 51.1986301369863
# (697,)
# (422,)
# (580,)
# (637,)
# prueba = 51.755136986301366
# (679,)
# (825,)
# (154,)
# (678,)
# validación = 27.78253424657534
# (684,)
# (855,)
# (127,)
# (670,)
# prueba = 28.63869863013699
# (802,)
# (458,)
# (272,)
# (804,)
# validación = 35.01712328767123
# (844,)
# (454,)
# (263,)
# (775,)
# prueba = 35.70205479452055
# (668,)
# (416,)
# (619,)
# (633,)
# validación = 48.97260273972603
# (679,)
# (412,)
# (606,)
# (639,)
# prueba = 52.696917808219176
# (642,)
# (428,)
# (592,)
# (674,)
# validación = 54.36643835616438
# (670,)
# (407,)
# (576,)
# (683,)
# prueba = 53.5958904109589
# (372,)
# (391,)
# (495,)
# (1078,)
# validación = 27.18321917808219
# (365,)
# (356,)
# (539,)
# (1076,)
# prueba = 27.69691780821918
# (828,)
# (276,)
# (543,)
# (689,)
# validación = 41.78082191780822
# (786,)
# (270,)
# (535,)
# (745,)
# prueba = 44.263698630136986
# (692,)
# (347,)
# (626,)
# (671,)
# validación = 49.44349315068493
# (671,)
# (380,)
# (617,)
# (668,)
# prueba = 49.78595890410959
# (608,)
# (500,)
# (577,)
# (651,)
# validación = 51.71232876712328
# (658,)
# (452,)
# (575,)
# (651,)
# prueba = 53.21061643835616
# (1117,)
# (357,)
# (372,)
# (490,)
# validación = 26.32705479452055
# (1130,)
# (306,)
# (420,)
# (480,)
# prueba = 29.40924657534247
# (531,)
# (422,)
# (613,)
# (770,)
# validación = 43.36472602739726
# (501,)
# (407,)
# (620,)
# (808,)
# prueba = 43.53595890410959
# (696,)
# (365,)
# (602,)
# (673,)
# validación = 47.68835616438356
# (619,)
# (356,)
# (665,)
# (696,)
# prueba = 50.08561643835616
# (573,)
# (344,)
# (694,)
# (725,)
# validación = 50.042808219178085
# (636,)
# (317,)
# (695,)
# (688,)
# prueba = 51.284246575342465
# (1045,)
# (427,)
# (314,)
# (550,)
# validación = 27.868150684931507
# (1074,)
# (431,)
# (303,)
# (528,)
# prueba = 27.52568493150685
# (756,)
# (265,)
# (714,)
# (601,)
# validación = 39.38356164383562
# (766,)
# (271,)
# (672,)
# (627,)
# prueba = 42.03767123287671
# (851,)
# (372,)
# (362,)
# (751,)
# validación = 39.25513698630137
# (889,)
# (338,)
# (350,)
# (759,)
# prueba = 41.909246575342465
# (844,)
# (242,)
# (564,)
# (686,)
# validación = 44.30650684931507
# (872,)
# (234,)
# (574,)
# (656,)
# prueba = 44.77739726027397
# (651,)
# (358,)
# (628,)
# (699,)
# validación = 25.81335616438356
# (630,)
# (386,)
# (602,)
# (718,)
# prueba = 26.583904109589042
# (719,)
# (165,)
# (252,)
# (1200,)
# validación = 29.62328767123288
# (702,)
# (192,)
# (229,)
# (1213,)
# prueba = 30.65068493150685
# (583,)
# (462,)
# (633,)
# (658,)
# validación = 38.65582191780822
# (562,)
# (462,)
# (638,)
# (674,)
# prueba = 39.04109589041096
# (685,)
# (451,)
# (554,)
# (646,)
# validación = 39.726027397260275
# (721,)
# (425,)
# (554,)
# (636,)
# prueba = 39.59760273972603
# (864,)
# (367,)
# (201,)
# (904,)
# validación = 26.32705479452055
# (825,)
# (359,)
# (196,)
# (956,)
# prueba = 25.12842465753425
# (848,)
# (250,)
# (189,)
# (1049,)
# validación = 32.61986301369863
# (871,)
# (244,)
# (184,)
# (1037,)
# prueba = 34.375
# (632,)
# (461,)
# (606,)
# (637,)
# validación = 39.25513698630137
# (620,)
# (467,)
# (584,)
# (665,)
# prueba = 42.38013698630137
# (645,)
# (455,)
# (649,)
# (587,)
# validación = 39.8972602739726
# (654,)
# (413,)
# (677,)
# (592,)
# prueba = 40.45376712328767
# (528,)
# (368,)
# (276,)
# (1164,)
# validación = 26.79794520547945
# (527,)
# (299,)
# (298,)
# (1212,)
# prueba = 27.31164383561644
# (802,)
# (274,)
# (534,)
# (726,)
# validación = 30.136986301369863
# (848,)
# (236,)
# (548,)
# (704,)
# prueba = 31.549657534246577
# (567,)
# (429,)
# (633,)
# (707,)
# validación = 41.39554794520548
# (610,)
# (419,)
# (579,)
# (728,)
# prueba = 43.53595890410959
# (635,)
# (437,)
# (636,)
# (628,)
# validación = 41.65239726027397
# (632,)
# (434,)
# (616,)
# (654,)
# prueba = 41.053082191780824
# (428,)
# (574,)
# (569,)
# (765,)
# validación = 25.94178082191781
# (399,)
# (604,)
# (557,)
# (776,)
# prueba = 27.440068493150683
# (582,)
# (244,)
# (644,)
# (866,)
# validación = 35.53082191780822
# (585,)
# (236,)
# (655,)
# (860,)
# prueba = 35.91609589041096
# (677,)
# (405,)
# (576,)
# (678,)
# validación = 37.58561643835616
# (650,)
# (378,)
# (587,)
# (721,)
# prueba = 38.91267123287671
# (699,)
# (344,)
# (551,)
# (742,)
# validación = 41.56678082191781
# (714,)
# (341,)
# (583,)
# (698,)
# prueba = 40.32534246575342
# (571,)
# (374,)
# (775,)
# (616,)
# validación = 25.684931506849317
# (568,)
# (336,)
# (801,)
# (631,)
# prueba = 26.62671232876712
# (768,)
# (432,)
# (376,)
# (760,)
# validación = 37.58561643835616
# (774,)
# (436,)
# (390,)
# (736,)
# prueba = 36.601027397260275
# (593,)
# (444,)
# (525,)
# (774,)
# validación = 36.17294520547945
# (598,)
# (357,)
# (506,)
# (875,)
# prueba = 36.64383561643836
# (678,)
# (425,)
# (530,)
# (703,)
# validación = 39.51198630136986
# (697,)
# (417,)
# (462,)
# (760,)
# prueba = 42.03767123287671
# (436,)
# (561,)
# (554,)
# (785,)
# validación = 25.81335616438356
# (447,)
# (552,)
# (539,)
# (798,)
# prueba = 26.027397260273972
# (753,)
# (141,)
# (663,)
# (779,)
# validación = 31.934931506849317
# (787,)
# (149,)
# (682,)
# (718,)
# prueba = 34.11815068493151
# (707,)
# (419,)
# (521,)
# (689,)
# validación = 40.667808219178085
# (684,)
# (404,)
# (558,)
# (690,)
# prueba = 39.38356164383562
# (778,)
# (387,)
# (454,)
# (717,)
# validación = 38.398972602739725
# (747,)
# (369,)
# (512,)
# (708,)
# prueba = 40.32534246575342
# (368,)
# (1337,)
# (315,)
# (316,)
# validación = 27.26883561643836
# (324,)
# (1345,)
# (309,)
# (358,)
# prueba = 26.541095890410958
# (227,)
# (470,)
# (867,)
# (772,)
# validación = 33.090753424657535
# (203,)
# (480,)
# (913,)
# (740,)
# prueba = 34.54623287671233
# (592,)
# (392,)
# (720,)
# (632,)
# validación = 35.5736301369863
# (573,)
# (407,)
# (720,)
# (636,)
# prueba = 37.32876712328767
# (668,)
# (497,)
# (421,)
# (750,)
# validación = 42.93664383561644
# (678,)
# (468,)
# (487,)
# (703,)
# prueba = 40.71061643835616
# (612,)
# (919,)
# (323,)
# (482,)
# validación = 26.36986301369863
# (649,)
# (932,)
# (326,)
# (429,)
# prueba = 26.113013698630137
# (972,)
# (608,)
# (128,)
# (628,)
# validación = 31.20719178082192
# (1028,)
# (551,)
# (126,)
# (631,)
# prueba = 31.7208904109589
# (613,)
# (352,)
# (680,)
# (691,)
# validación = 39.76883561643836
# (619,)
# (320,)
# (691,)
# (706,)
# prueba = 39.68321917808219
# (722,)
# (411,)
# (543,)
# (660,)
# validación = 38.61301369863014
# (718,)
# (396,)
# (568,)
# (654,)
# prueba = 39.55479452054795
# (1602,)
# (579,)
# (2,)
# (153,)
# validación = 26.79794520547945
# (1546,)
# (577,)
# (3,)
# (210,)
# prueba = 29.02397260273973
# (778,)
# (772,)
# (0,)
# (786,)
# validación = 33.81849315068493
# (791,)
# (748,)
# (0,)
# (797,)
# prueba = 36.00171232876712
# (914,)
# (120,)
# (640,)
# (662,)
# validación = 35.31678082191781
# (934,)
# (118,)
# (601,)
# (683,)
# prueba = 38.52739726027397
# (628,)
# (294,)
# (656,)
# (758,)
# validación = 37.9708904109589
# (663,)
# (290,)
# (609,)
# (774,)
# prueba = 38.86986301369863

# %%
63,63  82,82
63,56  79,80
63,42  78,79
56,42  78,79
56,28  78,79
49,56  79,80
49,42  79,80
35,63  74,76

# %% [markdown]
# ### Ver mejor Lambda

# %% [markdown]
# #### sin normalizar

# %%
redes = [[56, 56], [56, 63]]
Lambdas = [0.001, 0.01, 0.1]

for red in redes:

    r = red_neuronal(2, red, 0.12, Ex.shape[1], 4)

    for L in Lambdas:

        iteraciones = [50, 100, 300, 500, 700, 1000]
        validaciones = []
        pruebas = []

        for i in range(len(iteraciones)):
            p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
            validaciones.append(p1)
            pruebas.append(p2)

        plt.figure()
        plt.title("red: {}, Lambda = {}".format(red, L))
        plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
        plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
        plt.show()
# Out:
# (808,)
# (223,)
# (568,)
# (737,)
# validación = 30.993150684931507
# (751,)
# (220,)
# (591,)
# (774,)
# prueba = 30.86472602739726
# (763,)
# (296,)
# (577,)
# (700,)
# validación = 56.849315068493155
# (744,)
# (264,)
# (595,)
# (733,)
# prueba = 58.60445205479452
# (632,)
# (563,)
# (576,)
# (565,)
# validación = 74.14383561643835
# (610,)
# (530,)
# (611,)
# (585,)
# prueba = 74.14383561643835
# (583,)
# (593,)
# (595,)
# (565,)
# validación = 68.23630136986301
# (561,)
# (608,)
# (577,)
# (590,)
# prueba = 67.33732876712328
# (611,)
# (585,)
# (590,)
# (550,)
# validación = 68.23630136986301
# (580,)
# (568,)
# (580,)
# (608,)
# prueba = 69.86301369863014
# (550,)
# (584,)
# (634,)
# (568,)
# validación = 66.26712328767124
# (550,)
# (557,)
# (630,)
# (599,)
# prueba = 66.43835616438356
# (667,)
# (547,)
# (523,)
# (599,)
# validación = 32.27739726027397
# (721,)
# (535,)
# (474,)
# (606,)
# prueba = 31.07876712328767
# (817,)
# (344,)
# (261,)
# (914,)
# validación = 37.542808219178085
# (810,)
# (337,)
# (280,)
# (909,)
# prueba = 39.726027397260275
# (645,)
# (553,)
# (590,)
# (548,)
# validación = 73.8013698630137
# (558,)
# (564,)
# (614,)
# (600,)
# prueba = 73.75856164383562
# (608,)
# (608,)
# (569,)
# (551,)
# validación = 68.62157534246576
# (572,)
# (537,)
# (625,)
# (602,)
# prueba = 70.84760273972603
# (639,)
# (569,)
# (581,)
# (547,)
# validación = 67.72260273972603
# (613,)
# (543,)
# (601,)
# (579,)
# prueba = 66.43835616438356
# (624,)
# (579,)
# (579,)
# (554,)
# validación = 70.4195205479452
# (603,)
# (556,)
# (591,)
# (586,)
# prueba = 69.13527397260275
# (571,)
# (591,)
# (495,)
# (679,)
# validación = 35.659246575342465
# (579,)
# (593,)
# (462,)
# (702,)
# prueba = 36.215753424657535
# (684,)
# (539,)
# (444,)
# (669,)
# validación = 54.0667808219178
# (662,)
# (527,)
# (438,)
# (709,)
# prueba = 53.5958904109589
# (628,)
# (531,)
# (611,)
# (566,)
# validación = 74.14383561643835
# (607,)
# (517,)
# (612,)
# (600,)
# prueba = 76.71232876712328
# (615,)
# (544,)
# (619,)
# (558,)
# validación = 76.41267123287672
# (601,)
# (547,)
# (604,)
# (584,)
# prueba = 76.02739726027397
# (609,)
# (572,)
# (595,)
# (560,)
# validación = 78.76712328767124
# (582,)
# (519,)
# (630,)
# (605,)
# prueba = 78.98116438356165
# (613,)
# (563,)
# (618,)
# (542,)
# validación = 79.28082191780823
# (618,)
# (527,)
# (614,)
# (577,)
# prueba = 79.7945205479452
# (571,)
# (656,)
# (286,)
# (823,)
# validación = 29.36643835616438
# (513,)
# (689,)
# (294,)
# (840,)
# prueba = 28.68150684931507
# (689,)
# (388,)
# (588,)
# (671,)
# validación = 53.339041095890416
# (770,)
# (363,)
# (541,)
# (662,)
# prueba = 53.724315068493155
# (623,)
# (544,)
# (615,)
# (554,)
# validación = 74.14383561643835
# (616,)
# (546,)
# (582,)
# (592,)
# prueba = 74.44349315068493
# (616,)
# (560,)
# (614,)
# (546,)
# validación = 73.50171232876713
# (579,)
# (572,)
# (607,)
# (578,)
# prueba = 74.10102739726028
# (603,)
# (577,)
# (594,)
# (562,)
# validación = 65.23972602739725
# (583,)
# (556,)
# (611,)
# (586,)
# prueba = 66.05308219178082
# (577,)
# (576,)
# (637,)
# (546,)
# validación = 64.21232876712328
# (578,)
# (584,)
# (575,)
# (599,)
# prueba = 67.8082191780822
# (782,)
# (402,)
# (550,)
# (602,)
# validación = 29.708904109589042
# (738,)
# (377,)
# (587,)
# (634,)
# prueba = 30.0513698630137
# (619,)
# (446,)
# (667,)
# (604,)
# validación = 54.75171232876712
# (624,)
# (386,)
# (656,)
# (670,)
# prueba = 57.57705479452054
# (628,)
# (549,)
# (579,)
# (580,)
# validación = 72.6027397260274
# (615,)
# (525,)
# (591,)
# (605,)
# prueba = 73.50171232876713
# (604,)
# (578,)
# (584,)
# (570,)
# validación = 72.51712328767124
# (592,)
# (539,)
# (609,)
# (596,)
# prueba = 73.0736301369863
# (623,)
# (561,)
# (596,)
# (556,)
# validación = 71.53253424657534
# (593,)
# (555,)
# (596,)
# (592,)
# prueba = 71.53253424657534
# (594,)
# (593,)
# (572,)
# (577,)
# validación = 72.30308219178082
# (625,)
# (533,)
# (576,)
# (602,)
# prueba = 71.74657534246576
# (654,)
# (298,)
# (569,)
# (815,)
# validación = 36.51541095890411
# (660,)
# (266,)
# (565,)
# (845,)
# prueba = 37.542808219178085
# (689,)
# (470,)
# (480,)
# (697,)
# validación = 50.4708904109589
# (647,)
# (485,)
# (488,)
# (716,)
# prueba = 54.109589041095894
# (612,)
# (531,)
# (618,)
# (575,)
# validación = 73.63013698630137
# (626,)
# (523,)
# (575,)
# (612,)
# prueba = 73.92979452054794
# (616,)
# (561,)
# (595,)
# (564,)
# validación = 77.99657534246576
# (610,)
# (540,)
# (600,)
# (586,)
# prueba = 79.1095890410959
# (631,)
# (556,)
# (597,)
# (552,)
# validación = 85.40239726027397
# (619,)
# (530,)
# (591,)
# (596,)
# prueba = 85.5736301369863
# (641,)
# (550,)
# (579,)
# (566,)
# validación = 85.91609589041096
# (651,)
# (520,)
# (570,)
# (595,)
# prueba = 86.25856164383562

# %% [markdown]
# #### normalizando

# %%
redes = [[56, 63]]
Lambdas = [0, 0.001, 0.01, 0.1, 1, 10, 100]

for red in redes:

    r = red_neuronal(2, red, 0.12, Ex2.shape[1], 4)

    for L in Lambdas:

        iteraciones = [50, 100, 300, 500, 700, 1000]
        validaciones = []
        pruebas = []

        for i in range(len(iteraciones)):
            p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, L, iteraciones[i], INIT_EPSILON)
            validaciones.append(p1)
            pruebas.append(p2)

        plt.figure()
        plt.title("red: {}, Lambda = {}".format(red, L))
        plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
        plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
        plt.show()
# Out:
# (368,)
# (866,)
# (161,)
# (941,)
# validación = 25.04280821917808
# (401,)
# (848,)
# (141,)
# (946,)
# prueba = 25.55650684931507
# (766,)
# (694,)
# (217,)
# (659,)
# validación = 29.580479452054792
# (844,)
# (648,)
# (207,)
# (637,)
# prueba = 31.12157534246575
# (659,)
# (508,)
# (639,)
# (530,)
# validación = 65.28253424657534
# (645,)
# (463,)
# (655,)
# (573,)
# prueba = 67.25171232876713
# (679,)
# (555,)
# (523,)
# (579,)
# validación = 76.58390410958904
# (676,)
# (539,)
# (505,)
# (616,)
# prueba = 76.75513698630137
# (648,)
# (571,)
# (555,)
# (562,)
# validación = 83.94691780821918
# (628,)
# (555,)
# (563,)
# (590,)
# prueba = 86.00171232876713
# (614,)
# (582,)
# (580,)
# (560,)
# validación = 83.26198630136986
# (590,)
# (548,)
# (602,)
# (596,)
# prueba = 85.87328767123287
# (802,)
# (143,)
# (295,)
# (1096,)
# validación = 27.14041095890411
# (886,)
# (123,)
# (277,)
# (1050,)
# prueba = 28.767123287671232
# (1534,)
# (248,)
# (60,)
# (494,)
# validación = 33.56164383561644
# (1567,)
# (237,)
# (60,)
# (472,)
# prueba = 34.07534246575342
# (800,)
# (589,)
# (370,)
# (577,)
# validación = 65.19691780821918
# (801,)
# (584,)
# (371,)
# (580,)
# prueba = 66.30993150684932
# (699,)
# (534,)
# (561,)
# (542,)
# validación = 78.8527397260274
# (662,)
# (522,)
# (589,)
# (563,)
# prueba = 79.28082191780823
# (623,)
# (579,)
# (586,)
# (548,)
# validación = 81.76369863013699
# (628,)
# (555,)
# (561,)
# (592,)
# prueba = 82.7054794520548
# (605,)
# (563,)
# (590,)
# (578,)
# validación = 85.91609589041096
# (619,)
# (552,)
# (581,)
# (584,)
# prueba = 86.72945205479452
# (675,)
# (983,)
# (7,)
# (671,)
# validación = 26.96917808219178
# (689,)
# (927,)
# (7,)
# (713,)
# prueba = 27.52568493150685
# (208,)
# (839,)
# (306,)
# (983,)
# validación = 28.93835616438356
# (230,)
# (784,)
# (304,)
# (1018,)
# prueba = 30.222602739726028
# (938,)
# (371,)
# (503,)
# (524,)
# validación = 47.90239726027397
# (899,)
# (360,)
# (519,)
# (558,)
# prueba = 48.97260273972603
# (711,)
# (541,)
# (518,)
# (566,)
# validación = 77.52568493150685
# (708,)
# (544,)
# (506,)
# (578,)
# prueba = 77.73972602739725
# (649,)
# (595,)
# (550,)
# (542,)
# validación = 83.86130136986301
# (647,)
# (553,)
# (555,)
# (581,)
# prueba = 85.14554794520548
# (613,)
# (569,)
# (578,)
# (576,)
# validación = 85.87328767123287
# (619,)
# (558,)
# (581,)
# (578,)
# prueba = 87.28595890410958
# (615,)
# (683,)
# (292,)
# (746,)
# validación = 27.73972602739726
# (616,)
# (651,)
# (291,)
# (778,)
# prueba = 28.767123287671232
# (745,)
# (544,)
# (234,)
# (813,)
# validación = 28.63869863013699
# (723,)
# (565,)
# (218,)
# (830,)
# prueba = 28.51027397260274
# (774,)
# (265,)
# (739,)
# (558,)
# validación = 36.00171232876712
# (754,)
# (249,)
# (789,)
# (544,)
# prueba = 36.34417808219178
# (913,)
# (587,)
# (281,)
# (555,)
# validación = 63.91267123287672
# (948,)
# (566,)
# (266,)
# (556,)
# prueba = 64.6832191780822
# (497,)
# (834,)
# (422,)
# (583,)
# validación = 32.87671232876712
# (525,)
# (823,)
# (414,)
# (574,)
# prueba = 33.00513698630137
# (866,)
# (502,)
# (444,)
# (524,)
# validación = 67.46575342465754
# (859,)
# (501,)
# (399,)
# (577,)
# prueba = 69.04965753424658
# (929,)
# (1010,)
# (4,)
# (393,)
# validación = 27.26883561643836
# (965,)
# (967,)
# (3,)
# (401,)
# prueba = 27.482876712328768
# (162,)
# (282,)
# (886,)
# (1006,)
# validación = 25.04280821917808
# (156,)
# (242,)
# (878,)
# (1060,)
# prueba = 27.825342465753423
# (740,)
# (673,)
# (49,)
# (874,)
# validación = 24.785958904109588
# (716,)
# (657,)
# (57,)
# (906,)
# prueba = 26.49828767123288
# (573,)
# (788,)
# (16,)
# (959,)
# validación = 26.669520547945208
# (574,)
# (794,)
# (22,)
# (946,)
# prueba = 27.18321917808219
# (336,)
# (870,)
# (30,)
# (1100,)
# validación = 25.34246575342466
# (384,)
# (859,)
# (17,)
# (1076,)
# prueba = 24.82876712328767
# (898,)
# (712,)
# (4,)
# (722,)
# validación = 27.69691780821918
# (905,)
# (714,)
# (4,)
# (713,)
# prueba = 26.75513698630137
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095

# %%
redes = [[56, 56]]
Lambdas = [0.001, 0.01]

for red in redes:

    r = red_neuronal(2, red, 0.12, Ex2.shape[1], 4)

    for L in Lambdas:

        iteraciones = [50, 100, 300, 500, 700, 1000]
        validaciones = []
        pruebas = []

        for i in range(len(iteraciones)):
            p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, L, iteraciones[i], INIT_EPSILON)
            validaciones.append(p1)
            pruebas.append(p2)

        plt.figure()
        plt.title("red: {}, Lambda = {}".format(red, L))
        plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
        plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
        plt.show()
# Out:
# (699,)
# (276,)
# (746,)
# (615,)
# validación = 26.96917808219178
# (668,)
# (271,)
# (747,)
# (650,)
# prueba = 28.72431506849315
# (416,)
# (545,)
# (344,)
# (1031,)
# validación = 29.794520547945208
# (411,)
# (495,)
# (364,)
# (1066,)
# prueba = 30.522260273972602
# (823,)
# (565,)
# (388,)
# (560,)
# validación = 65.66780821917808
# (836,)
# (534,)
# (384,)
# (582,)
# prueba = 67.0804794520548
# (714,)
# (527,)
# (561,)
# (534,)
# validación = 76.9263698630137
# (713,)
# (500,)
# (523,)
# (600,)
# prueba = 77.78253424657534
# (657,)
# (571,)
# (563,)
# (545,)
# validación = 83.13356164383562
# (639,)
# (580,)
# (546,)
# (571,)
# prueba = 84.97431506849315
# (628,)
# (551,)
# (589,)
# (568,)
# validación = 84.07534246575342
# (608,)
# (574,)
# (566,)
# (588,)
# prueba = 85.53082191780823
# (498,)
# (613,)
# (311,)
# (914,)
# validación = 28.08219178082192
# (488,)
# (585,)
# (334,)
# (929,)
# prueba = 28.55308219178082
# (764,)
# (331,)
# (275,)
# (966,)
# validación = 28.29623287671233
# (776,)
# (309,)
# (237,)
# (1014,)
# prueba = 28.25342465753425
# (647,)
# (567,)
# (581,)
# (541,)
# validación = 58.775684931506845
# (658,)
# (525,)
# (580,)
# (573,)
# prueba = 59.28938356164384
# (665,)
# (588,)
# (552,)
# (531,)
# validación = 79.45205479452055
# (665,)
# (542,)
# (544,)
# (585,)
# prueba = 80.43664383561644
# (635,)
# (550,)
# (595,)
# (556,)
# validación = 83.94691780821918
# (636,)
# (558,)
# (560,)
# (582,)
# prueba = 83.81849315068493
# (616,)
# (573,)
# (587,)
# (560,)
# validación = 85.8304794520548
# (602,)
# (574,)
# (598,)
# (562,)
# prueba = 85.65924657534246

# %%
redes = [[63,63]]
Lambdas = [0.001, 0.01]

for red in redes:

    r = red_neuronal(2, red, 0.12, Ex2.shape[1], 4)

    for L in Lambdas:

        iteraciones = [50, 100, 300, 500, 700, 1000]
        validaciones = []
        pruebas = []

        for i in range(len(iteraciones)):
            p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, L, iteraciones[i], INIT_EPSILON)
            validaciones.append(p1)
            pruebas.append(p2)

        plt.figure()
        plt.title("red: {}, Lambda = {}".format(red, L))
        plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
        plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
        plt.show()
# Out:
# (647,)
# (512,)
# (437,)
# (740,)
# validación = 28.68150684931507
# (635,)
# (521,)
# (423,)
# (757,)
# prueba = 30.950342465753423
# (296,)
# (725,)
# (738,)
# (577,)
# validación = 36.68664383561644
# (298,)
# (645,)
# (800,)
# (593,)
# prueba = 38.48458904109589
# (759,)
# (569,)
# (467,)
# (541,)
# validación = 70.29109589041096
# (763,)
# (556,)
# (438,)
# (579,)
# prueba = 71.66095890410958
# (677,)
# (581,)
# (525,)
# (553,)
# validación = 79.62328767123287
# (694,)
# (522,)
# (527,)
# (593,)
# prueba = 81.63527397260275
# (640,)
# (578,)
# (535,)
# (583,)
# validación = 83.21917808219177
# (652,)
# (548,)
# (549,)
# (587,)
# prueba = 84.76027397260275
# (633,)
# (573,)
# (566,)
# (564,)
# validación = 83.1763698630137
# (604,)
# (558,)
# (593,)
# (581,)
# prueba = 84.88869863013699
# (693,)
# (741,)
# (440,)
# (462,)
# validación = 28.51027397260274
# (693,)
# (714,)
# (440,)
# (489,)
# prueba = 27.99657534246575
# (823,)
# (257,)
# (287,)
# (969,)
# validación = 33.34760273972603
# (832,)
# (240,)
# (327,)
# (937,)
# prueba = 34.20376712328767
# (896,)
# (569,)
# (340,)
# (531,)
# validación = 59.76027397260274
# (906,)
# (541,)
# (322,)
# (567,)
# prueba = 60.830479452054796
# (703,)
# (586,)
# (515,)
# (532,)
# validación = 75.77054794520548
# (683,)
# (533,)
# (545,)
# (575,)
# prueba = 77.52568493150685
# (603,)
# (591,)
# (585,)
# (557,)
# validación = 86.00171232876713
# (599,)
# (558,)
# (587,)
# (592,)
# prueba = 85.95890410958904
# (615,)
# (575,)
# (592,)
# (554,)
# validación = 87.84246575342466
# (616,)
# (551,)
# (582,)
# (587,)
# prueba = 88.82705479452055

# %%
[63,63] con 0.01 es la mejor 87,88

# %% [markdown]
# ### Añadir una tercera capa

# %%
56,56,56   80,82
56,56,7    81,83
63,56,63   77,76
56,63,56   84,84
56,63,49   82,83

# %%
nodos = [63, 56, 49, 42, 35, 28, 21, 14, 7]
Lambdas = [0.01]

for r1 in nodos:

    r = red_neuronal(3, [63, 63, r1], 0.12, Ex2.shape[1], 4)

    for L in Lambdas:

        iteraciones = [50, 100, 500, 1000]
        validaciones = []
        pruebas = []

        for i in range(len(iteraciones)):
            p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, L, iteraciones[i], INIT_EPSILON)
            validaciones.append(p1)
            pruebas.append(p2)

    plt.figure()
    plt.title("red: {}".format([63, 63, r1]))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (1055,)
# (231,)
# (4,)
# (1046,)
# validación = 25.89897260273973
# (1088,)
# (217,)
# (1,)
# (1030,)
# prueba = 27.868150684931507
# (1478,)
# (150,)
# (21,)
# (687,)
# validación = 27.95376712328767
# (1508,)
# (138,)
# (14,)
# (676,)
# prueba = 28.809931506849317
# (729,)
# (607,)
# (468,)
# (532,)
# validación = 68.75
# (723,)
# (585,)
# (456,)
# (572,)
# prueba = 70.4195205479452
# (634,)
# (590,)
# (578,)
# (534,)
# validación = 83.47602739726028
# (637,)
# (543,)
# (586,)
# (570,)
# prueba = 84.71746575342466
# (1252,)
# (1,)
# (130,)
# (953,)
# validación = 26.96917808219178
# (1272,)
# (0,)
# (129,)
# (935,)
# prueba = 27.69691780821918
# (66,)
# (60,)
# (1813,)
# (397,)
# validación = 32.23458904109589
# (62,)
# (50,)
# (1760,)
# (464,)
# prueba = 33.13356164383562
# (819,)
# (628,)
# (314,)
# (575,)
# validación = 62.457191780821915
# (780,)
# (597,)
# (365,)
# (594,)
# prueba = 64.51198630136986
# (611,)
# (586,)
# (590,)
# (549,)
# validación = 83.09075342465754
# (625,)
# (553,)
# (602,)
# (556,)
# prueba = 84.24657534246576
# (14,)
# (241,)
# (1126,)
# (955,)
# validación = 25.34246575342466
# (13,)
# (235,)
# (1101,)
# (987,)
# prueba = 28.29623287671233
# (1232,)
# (117,)
# (334,)
# (653,)
# validación = 31.892123287671232
# (1226,)
# (89,)
# (390,)
# (631,)
# prueba = 32.32020547945205
# (796,)
# (644,)
# (362,)
# (534,)
# validación = 62.79965753424658
# (824,)
# (578,)
# (372,)
# (562,)
# prueba = 65.02568493150685
# (598,)
# (599,)
# (601,)
# (538,)
# validación = 83.4332191780822
# (593,)
# (565,)
# (595,)
# (583,)
# prueba = 85.48801369863014
# (422,)
# (1191,)
# (28,)
# (695,)
# validación = 26.62671232876712
# (459,)
# (1139,)
# (27,)
# (711,)
# prueba = 28.51027397260274
# (796,)
# (397,)
# (379,)
# (764,)
# validación = 31.12157534246575
# (799,)
# (355,)
# (403,)
# (779,)
# prueba = 33.30479452054795
# (754,)
# (571,)
# (456,)
# (555,)
# validación = 68.79280821917808
# (770,)
# (497,)
# (479,)
# (590,)
# prueba = 68.70719178082192
# (616,)
# (589,)
# (588,)
# (543,)
# validación = 82.49143835616438
# (619,)
# (582,)
# (559,)
# (576,)
# prueba = 83.3904109589041
# (773,)
# (0,)
# (1547,)
# (16,)
# validación = 25.214041095890412
# (759,)
# (0,)
# (1551,)
# (26,)
# prueba = 26.28424657534247
# (1681,)
# (95,)
# (2,)
# (558,)
# validación = 30.26541095890411
# (1669,)
# (101,)
# (2,)
# (564,)
# prueba = 31.892123287671232
# (725,)
# (594,)
# (507,)
# (510,)
# validación = 72.04623287671232
# (718,)
# (578,)
# (485,)
# (555,)
# prueba = 74.35787671232876
# (652,)
# (576,)
# (582,)
# (526,)
# validación = 80.47945205479452
# (626,)
# (544,)
# (594,)
# (572,)
# prueba = 82.87671232876713
# (909,)
# (390,)
# (11,)
# (1026,)
# validación = 25.0
# (889,)
# (399,)
# (12,)
# (1036,)
# prueba = 27.054794520547947
# (9,)
# (531,)
# (1296,)
# (500,)
# validación = 28.98116438356164
# (7,)
# (489,)
# (1343,)
# (497,)
# prueba = 31.164383561643838
# (783,)
# (783,)
# (292,)
# (478,)
# validación = 56.035958904109584
# (805,)
# (744,)
# (258,)
# (529,)
# prueba = 58.476027397260275
# (610,)
# (568,)
# (606,)
# (552,)
# validación = 84.50342465753424
# (607,)
# (569,)
# (573,)
# (587,)
# prueba = 85.44520547945206
# (490,)
# (792,)
# (347,)
# (707,)
# validación = 28.210616438356162
# (551,)
# (764,)
# (335,)
# (686,)
# prueba = 28.46746575342466
# (0,)
# (269,)
# (1654,)
# (413,)
# validación = 30.7791095890411
# (0,)
# (265,)
# (1654,)
# (417,)
# prueba = 31.977739726027398
# (871,)
# (667,)
# (304,)
# (494,)
# validación = 61.130136986301366
# (832,)
# (677,)
# (332,)
# (495,)
# prueba = 61.64383561643836
# (694,)
# (552,)
# (566,)
# (524,)
# validación = 75.64212328767124
# (696,)
# (572,)
# (522,)
# (546,)
# prueba = 77.31164383561644
# (2228,)
# (0,)
# (0,)
# (108,)
# validación = 26.41267123287671
# (2219,)
# (0,)
# (0,)
# (117,)
# prueba = 26.669520547945208
# (1021,)
# (572,)
# (40,)
# (703,)
# validación = 29.02397260273973
# (998,)
# (508,)
# (55,)
# (775,)
# prueba = 28.68150684931507
# (683,)
# (591,)
# (507,)
# (555,)
# validación = 65.19691780821918
# (710,)
# (565,)
# (489,)
# (572,)
# prueba = 66.05308219178082
# (613,)
# (560,)
# (614,)
# (549,)
# validación = 82.66267123287672
# (613,)
# (563,)
# (572,)
# (588,)
# prueba = 84.03253424657534
# (0,)
# (492,)
# (0,)
# (1844,)
# validación = 24.18664383561644
# (0,)
# (462,)
# (0,)
# (1874,)
# prueba = 25.214041095890412
# (0,)
# (168,)
# (1574,)
# (594,)
# validación = 28.98116438356164
# (0,)
# (193,)
# (1534,)
# (609,)
# prueba = 32.148972602739725
# (902,)
# (632,)
# (253,)
# (549,)
# validación = 59.07534246575342
# (896,)
# (592,)
# (263,)
# (585,)
# prueba = 61.986301369863014
# (735,)
# (761,)
# (291,)
# (549,)
# validación = 67.85102739726028
# (728,)
# (750,)
# (298,)
# (560,)
# prueba = 69.39212328767124

# %%
63,63,49      83,85
63,63,28      84,85
63,63,14      82,84

# %%
redes = [[56,56,56], [56,56,7],[56,63,56],[56,63,49]]
Lambdas = [0.001, 0.01]

for red in redes:

    r = red_neuronal(3, red, 0.12, Ex2.shape[1], 4)

    for L in Lambdas:

        iteraciones = [50, 100, 300, 500]
        validaciones = []
        pruebas = []

        for i in range(len(iteraciones)):
            p1, p2 = r.entrenar(Ex2, y_onehot, Vx2, Vy, Px2, Py, L, iteraciones[i], INIT_EPSILON)
            validaciones.append(p1)
            pruebas.append(p2)

    plt.figure()
    plt.title("red: {}, Lambda = {}".format(red, L))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()

# %% [markdown]
# ### Añadir una cuarta capa
