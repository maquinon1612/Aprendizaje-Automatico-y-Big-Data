# %%
from creador_redes import *
import loader as ld
import fun_basicas as fun
import matplotlib.pyplot as plt

random_state = 2714
INIT_EPSILON = 0.12

# %%
Ex, Ey, Vx, Vy, Px, Py = ld.carga_Numpy(random_state)
y_onehot = fun.one_hot(Ey, 4)

# %%
r = red_neuronal(2, [34], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 100, INIT_EPSILON)
# Out:
# (670,)
# (403,)
# (558,)
# (705,)
# validación = 44.30650684931507
# (695,)
# (429,)
# (545,)
# (667,)
# prueba = 45.80479452054795
# (44.30650684931507, 45.80479452054795)

# %%
r = red_neuronal(2, [34, 17], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 100, INIT_EPSILON)
# Out:
# (495,)
# (492,)
# (673,)
# (676,)
# validación = 51.58390410958904
# (531,)
# (548,)
# (608,)
# (649,)
# prueba = 48.8013698630137
# (51.58390410958904, 48.8013698630137)

# %%
r = red_neuronal(2, [34, 17, 7], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 100, INIT_EPSILON)
# Out:
# (142,)
# (221,)
# (556,)
# (1417,)
# validación = 33.6472602739726
# (140,)
# (212,)
# (526,)
# (1458,)
# prueba = 34.67465753424658
# (33.6472602739726, 34.67465753424658)

# %%
r = red_neuronal(2, [34, 25, 17, 7], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 100, INIT_EPSILON)
# Out:
# validación = 24.743150684931507
# prueba = 24.101027397260275

# %%
r = red_neuronal(10, [10, 20, 30, 40, 50, 40, 30, 20, 10], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 1000, INIT_EPSILON)
# Out:
# validación = 24.743150684931507
# prueba = 24.101027397260275

# %%
r = red_neuronal(10, [10, 20, 30, 40, 100, 40, 30, 20, 10], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 1000, INIT_EPSILON)
# Out:
# validación = 24.743150684931507
# prueba = 24.101027397260275

# %%
r = red_neuronal(9, [100, 90, 80, 70, 60, 70, 80, 90, 100], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.1, 1000, INIT_EPSILON)
# Out:
# validación = 24.743150684931507
# prueba = 24.101027397260275

# %%
r = red_neuronal(9, [100, 90, 80, 70, 60, 70, 80, 90, 100], 0.12, Ex.shape[1], 4)

r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, 1000, INIT_EPSILON)
# Out:
# validación = 24.743150684931507
# prueba = 24.101027397260275

# %%
r = red_neuronal(4, [64 for i in range(4)], 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500, 600, 700, 800, 1000]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
# Out:
# (2336,)
# (0,)
# (0,)
# (0,)
# validación = 24.57191780821918
# (2336,)
# (0,)
# (0,)
# (0,)
# prueba = 26.027397260273972
# (525,)
# (90,)
# (777,)
# (944,)
# validación = 28.93835616438356
# (581,)
# (88,)
# (787,)
# (880,)
# prueba = 28.125
# (657,)
# (1412,)
# (267,)
# (0,)
# validación = 27.78253424657534
# (613,)
# (1452,)
# (271,)
# (0,)
# prueba = 28.424657534246577
# (739,)
# (919,)
# (68,)
# (610,)
# validación = 50.85616438356164
# (764,)
# (904,)
# (80,)
# (588,)
# prueba = 51.54109589041096
# (569,)
# (518,)
# (632,)
# (617,)
# validación = 69.52054794520548
# (637,)
# (485,)
# (628,)
# (586,)
# prueba = 67.67979452054794
# (670,)
# (482,)
# (607,)
# (577,)
# validación = 69.0068493150685
# (701,)
# (507,)
# (606,)
# (522,)
# prueba = 67.20890410958904
# (576,)
# (620,)
# (566,)
# (574,)
# validación = 76.1986301369863
# (622,)
# (587,)
# (577,)
# (550,)
# prueba = 73.84417808219177
# (594,)
# (573,)
# (578,)
# (591,)
# validación = 72.3458904109589
# (627,)
# (561,)
# (581,)
# (567,)
# prueba = 71.70376712328768
# (572,)
# (613,)
# (555,)
# (596,)
# validación = 69.04965753424658
# (614,)
# (631,)
# (539,)
# (552,)
# prueba = 68.23630136986301
# (578,)
# (579,)
# (575,)
# (604,)
# validación = 72.90239726027397
# (610,)
# (560,)
# (595,)
# (571,)
# prueba = 73.58732876712328
# (583,)
# (600,)
# (589,)
# (564,)
# validación = 73.88698630136986
# (590,)
# (604,)
# (589,)
# (553,)
# prueba = 74.35787671232876

# %%
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()

# %%
r = red_neuronal(4, [60, 34, 17, 7], 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500, 600, 700, 800, 1000 , 1200, 1400, 1500, 1700, 2000]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (0,)
# (0,)
# (2336,)
# validación = 24.743150684931507
# (0,)
# (0,)
# (0,)
# (2336,)
# prueba = 24.101027397260275
# (0,)
# (0,)
# (0,)
# (2336,)
# validación = 24.743150684931507
# (0,)
# (0,)
# (0,)
# (2336,)
# prueba = 24.101027397260275
# (701,)
# (0,)
# (1342,)
# (293,)
# validación = 31.549657534246577
# (787,)
# (0,)
# (1313,)
# (236,)
# prueba = 32.06335616438356
# (727,)
# (984,)
# (5,)
# (620,)
# validación = 52.44006849315068
# (735,)
# (994,)
# (13,)
# (594,)
# prueba = 51.369863013698634
# (983,)
# (135,)
# (628,)
# (590,)
# validación = 58.04794520547946
# (992,)
# (136,)
# (622,)
# (586,)
# prueba = 57.10616438356164
# (878,)
# (644,)
# (199,)
# (615,)
# validación = 59.417808219178085
# (940,)
# (608,)
# (196,)
# (592,)
# prueba = 60.18835616438356
# (628,)
# (500,)
# (617,)
# (591,)
# validación = 68.87842465753424
# (639,)
# (525,)
# (618,)
# (554,)
# prueba = 68.92123287671232
# (578,)
# (569,)
# (609,)
# (580,)
# validación = 67.59417808219177
# (639,)
# (552,)
# (584,)
# (561,)
# prueba = 66.6095890410959
# (586,)
# (571,)
# (598,)
# (581,)
# validación = 78.16780821917808
# (633,)
# (553,)
# (588,)
# (562,)
# prueba = 78.33904109589042
# (0,)
# (0,)
# (1,)
# (2335,)
# validación = 24.785958904109588
# (0,)
# (0,)
# (4,)
# (2332,)
# prueba = 24.143835616438356
# (572,)
# (611,)
# (561,)
# (592,)
# validación = 69.0068493150685
# (609,)
# (601,)
# (556,)
# (570,)
# prueba = 68.45034246575342
# (588,)
# (588,)
# (560,)
# (600,)
# validación = 70.07705479452055
# (623,)
# (576,)
# (537,)
# (600,)
# prueba = 69.7345890410959
# (556,)
# (526,)
# (635,)
# (619,)
# validación = 69.39212328767124
# (570,)
# (552,)
# (629,)
# (585,)
# prueba = 70.24828767123287
# (653,)
# (510,)
# (590,)
# (583,)
# validación = 62.5
# (711,)
# (490,)
# (560,)
# (575,)
# prueba = 61.25856164383562
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: divide by zero encountered in log
#   s1 = y * np.log(h)
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: invalid value encountered in multiply
#   s1 = y * np.log(h)
# (567,)
# (566,)
# (605,)
# (598,)
# validación = 73.50171232876713
# (602,)
# (591,)
# (581,)
# (562,)
# prueba = 72.73116438356165
# (557,)
# (454,)
# (714,)
# (611,)
# validación = 64.21232876712328
# (623,)
# (455,)
# (690,)
# (568,)
# prueba = 65.92465753424658

# %%
r = red_neuronal(4, [60, 34, 17, 7], 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]

for L in [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]:
    
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (930,)
# (131,)
# (0,)
# (1275,)
# validación = 25.59931506849315
# (936,)
# (129,)
# (0,)
# (1271,)
# prueba = 26.88356164383562
# (288,)
# (1781,)
# (48,)
# (219,)
# validación = 30.7791095890411
# (270,)
# (1761,)
# (67,)
# (238,)
# prueba = 30.522260273972602
# (712,)
# (782,)
# (251,)
# (591,)
# validación = 60.1027397260274
# (760,)
# (727,)
# (217,)
# (632,)
# prueba = 61.08732876712328
# (8,)
# (2328,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (13,)
# (2323,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (993,)
# (456,)
# (305,)
# (582,)
# validación = 58.26198630136986
# (986,)
# (454,)
# (270,)
# (626,)
# prueba = 59.589041095890416
# (613,)
# (587,)
# (564,)
# (572,)
# validación = 71.36130136986301
# (613,)
# (554,)
# (561,)
# (608,)
# prueba = 71.01883561643835
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (181,)
# (0,)
# (1892,)
# (263,)
# validación = 28.25342465753425
# (184,)
# (0,)
# (1906,)
# (246,)
# prueba = 29.96575342465753
# (1578,)
# (0,)
# (72,)
# (686,)
# validación = 38.784246575342465
# (1560,)
# (0,)
# (76,)
# (700,)
# prueba = 38.35616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (898,)
# (776,)
# (85,)
# (577,)
# validación = 59.203767123287676
# (880,)
# (755,)
# (97,)
# (604,)
# prueba = 60.53082191780822
# (0,)
# (2314,)
# (0,)
# (22,)
# validación = 26.49828767123288
# (0,)
# (2308,)
# (0,)
# (28,)
# prueba = 25.299657534246577
# (624,)
# (998,)
# (148,)
# (566,)
# validación = 64.12671232876713
# (620,)
# (947,)
# (149,)
# (620,)
# prueba = 64.21232876712328
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (998,)
# (0,)
# (1338,)
# validación = 23.501712328767123
# (0,)
# (949,)
# (0,)
# (1387,)
# prueba = 25.299657534246577
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2335,)
# (0,)
# (1,)
# validación = 25.89897260273973
# (0,)
# (2335,)
# (0,)
# (1,)
# prueba = 24.57191780821918
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (2336,)
# (0,)
# (0,)
# (0,)
# validación = 24.700342465753426
# (2336,)
# (0,)
# (0,)
# (0,)
# prueba = 24.44349315068493
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (0,)
# (0,)
# (2336,)
# validación = 23.8013698630137
# (0,)
# (0,)
# (0,)
# (2336,)
# prueba = 25.51369863013699
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095

# %%
r = red_neuronal(4, [60, 34, 17, 7], 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]

for L in [0.0001, 0.0003, 0.001, 0.003]:
    
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (771,)
# (767,)
# (0,)
# (798,)
# validación = 28.72431506849315
# (750,)
# (728,)
# (0,)
# (858,)
# prueba = 28.72431506849315
# (647,)
# (680,)
# (0,)
# (1009,)
# validación = 36.08732876712329
# (663,)
# (650,)
# (0,)
# (1023,)
# prueba = 36.34417808219178
# (369,)
# (699,)
# (678,)
# (590,)
# validación = 54.0667808219178
# (395,)
# (663,)
# (671,)
# (607,)
# prueba = 56.421232876712324
# (974,)
# (372,)
# (370,)
# (620,)
# validación = 53.125
# (937,)
# (370,)
# (373,)
# (656,)
# prueba = 55.86472602739726
# (648,)
# (553,)
# (580,)
# (555,)
# validación = 65.49657534246576
# (608,)
# (516,)
# (597,)
# (615,)
# prueba = 66.22431506849315
# (612,)
# (585,)
# (572,)
# (567,)
# validación = 63.955479452054796
# (577,)
# (578,)
# (587,)
# (594,)
# prueba = 64.25513698630137
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (26,)
# (280,)
# (0,)
# (2030,)
# validación = 24.65753424657534
# (34,)
# (278,)
# (0,)
# (2024,)
# prueba = 25.85616438356164
# (911,)
# (1252,)
# (0,)
# (173,)
# validación = 33.81849315068493
# (904,)
# (1242,)
# (0,)
# (190,)
# prueba = 33.56164383561644
# (803,)
# (715,)
# (235,)
# (583,)
# validación = 56.207191780821915
# (813,)
# (708,)
# (210,)
# (605,)
# prueba = 56.292808219178085
# (164,)
# (648,)
# (937,)
# (587,)
# validación = 55.47945205479452
# (144,)
# (626,)
# (950,)
# (616,)
# prueba = 55.60787671232876
# (574,)
# (558,)
# (648,)
# (556,)
# validación = 65.96746575342466
# (627,)
# (500,)
# (623,)
# (586,)
# prueba = 66.39554794520548
# (584,)
# (546,)
# (661,)
# (545,)
# validación = 67.67979452054794
# (540,)
# (548,)
# (653,)
# (595,)
# prueba = 67.46575342465754
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1038,)
# (1298,)
# (0,)
# (0,)
# validación = 25.085616438356162
# (1103,)
# (1233,)
# (0,)
# (0,)
# prueba = 25.085616438356162
# (0,)
# (299,)
# (1476,)
# (561,)
# validación = 39.29794520547945
# (0,)
# (278,)
# (1442,)
# (616,)
# prueba = 41.48116438356164
# (1148,)
# (563,)
# (55,)
# (570,)
# validación = 52.99657534246576
# (1130,)
# (553,)
# (63,)
# (590,)
# prueba = 53.724315068493155
# (826,)
# (884,)
# (13,)
# (613,)
# validación = 50.7277397260274
# (759,)
# (900,)
# (26,)
# (651,)
# prueba = 51.41267123287672
# (620,)
# (638,)
# (516,)
# (562,)
# validación = 67.33732876712328
# (611,)
# (621,)
# (528,)
# (576,)
# prueba = 68.23630136986301
# (608,)
# (527,)
# (645,)
# (556,)
# validación = 71.66095890410958
# (614,)
# (490,)
# (648,)
# (584,)
# prueba = 71.66095890410958
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (17,)
# (452,)
# (911,)
# (956,)
# validación = 26.070205479452053
# (18,)
# (420,)
# (941,)
# (957,)
# prueba = 26.79794520547945
# (1369,)
# (222,)
# (52,)
# (693,)
# validación = 36.68664383561644
# (1315,)
# (227,)
# (60,)
# (734,)
# prueba = 39.04109589041096
# (882,)
# (960,)
# (0,)
# (494,)
# validación = 36.25856164383562
# (896,)
# (921,)
# (0,)
# (519,)
# prueba = 39.16952054794521
# (796,)
# (641,)
# (307,)
# (592,)
# validación = 61.900684931506845
# (820,)
# (605,)
# (292,)
# (619,)
# prueba = 61.72945205479452
# (651,)
# (532,)
# (582,)
# (571,)
# validación = 66.26712328767124
# (666,)
# (529,)
# (531,)
# (610,)
# prueba = 67.12328767123287
# (568,)
# (595,)
# (618,)
# (555,)
# validación = 62.62842465753424
# (621,)
# (520,)
# (619,)
# (576,)
# prueba = 64.25513698630137

# %%
r = red_neuronal(4, [60, 34, 17, 7], 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (776,)
# (0,)
# (1086,)
# (474,)
# validación = 30.607876712328768
# (770,)
# (0,)
# (1047,)
# (519,)
# prueba = 30.00856164383562
# (1145,)
# (524,)
# (0,)
# (667,)
# validación = 48.715753424657535
# (1136,)
# (499,)
# (0,)
# (701,)
# prueba = 49.14383561643836
# (889,)
# (834,)
# (19,)
# (594,)
# validación = 55.43664383561644
# (852,)
# (851,)
# (14,)
# (619,)
# prueba = 55.69349315068494
# (796,)
# (405,)
# (577,)
# (558,)
# validación = 56.292808219178085
# (728,)
# (431,)
# (598,)
# (579,)
# prueba = 56.54965753424658
# (985,)
# (607,)
# (146,)
# (598,)
# validación = 53.339041095890416
# (962,)
# (572,)
# (169,)
# (633,)
# prueba = 54.28082191780822
# (629,)
# (528,)
# (610,)
# (569,)
# validación = 63.398972602739725
# (600,)
# (551,)
# (597,)
# (588,)
# prueba = 65.41095890410958

# %%
redes = []

for i in [7, 14, 21, 28, 35, 42, 49, 56, 63]:
    
    redes.reverse()
    redes.append(i)
    redes.reverse()
    
    r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

    iteraciones = [10, 50, 100, 200, 300, 400, 500]
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.title("tipo de red: {}".format(redes))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (1302,)
# (351,)
# (7,)
# (676,)
# validación = 27.18321917808219
# (1300,)
# (324,)
# (10,)
# (702,)
# prueba = 26.070205479452053
# (1082,)
# (495,)
# (73,)
# (686,)
# validación = 33.00513698630137
# (1130,)
# (462,)
# (90,)
# (654,)
# prueba = 35.35958904109589
# (973,)
# (294,)
# (227,)
# (842,)
# validación = 38.18493150684932
# (1015,)
# (308,)
# (213,)
# (800,)
# prueba = 39.16952054794521
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# (952,)
# (463,)
# (387,)
# (534,)
# validación = 41.053082191780824
# (934,)
# (434,)
# (379,)
# (589,)
# prueba = 41.909246575342465
# (995,)
# (442,)
# (170,)
# (729,)
# validación = 36.51541095890411
# (1006,)
# (431,)
# (187,)
# (712,)
# prueba = 34.50342465753425
# (1015,)
# (496,)
# (256,)
# (569,)
# validación = 51.11301369863014
# (1025,)
# (453,)
# (253,)
# (605,)
# prueba = 49.91438356164384
# (1146,)
# (528,)
# (47,)
# (615,)
# validación = 50.7277397260274
# (1165,)
# (488,)
# (41,)
# (642,)
# prueba = 52.3972602739726
# (111,)
# (100,)
# (0,)
# (2125,)
# validación = 23.0736301369863
# (114,)
# (87,)
# (0,)
# (2135,)
# prueba = 24.65753424657534
# (734,)
# (677,)
# (118,)
# (807,)
# validación = 28.55308219178082
# (690,)
# (704,)
# (128,)
# (814,)
# prueba = 26.84075342465753
# (791,)
# (41,)
# (734,)
# (770,)
# validación = 37.071917808219176
# (754,)
# (36,)
# (731,)
# (815,)
# prueba = 37.62842465753425
# (829,)
# (272,)
# (456,)
# (779,)
# validación = 41.60958904109589
# (841,)
# (278,)
# (441,)
# (776,)
# prueba = 41.78082191780822
# (776,)
# (248,)
# (466,)
# (846,)
# validación = 42.89383561643836
# (788,)
# (244,)
# (465,)
# (839,)
# prueba = 46.06164383561644
# (872,)
# (172,)
# (484,)
# (808,)
# validación = 41.48116438356164
# (887,)
# (189,)
# (459,)
# (801,)
# prueba = 43.53595890410959
# (934,)
# (258,)
# (431,)
# (713,)
# validación = 43.06506849315068
# (855,)
# (292,)
# (408,)
# (781,)
# prueba = 43.321917808219176
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (650,)
# (774,)
# (0,)
# (912,)
# validación = 26.9263698630137
# (723,)
# (714,)
# (0,)
# (899,)
# prueba = 27.054794520547947
# (1016,)
# (92,)
# (728,)
# (500,)
# validación = 36.81506849315068
# (1044,)
# (82,)
# (732,)
# (478,)
# prueba = 37.457191780821915
# (770,)
# (616,)
# (355,)
# (595,)
# validación = 52.6541095890411
# (795,)
# (582,)
# (324,)
# (635,)
# prueba = 52.6541095890411
# (714,)
# (423,)
# (590,)
# (609,)
# validación = 53.296232876712324
# (702,)
# (437,)
# (538,)
# (659,)
# prueba = 53.03938356164384
# (761,)
# (489,)
# (517,)
# (569,)
# validación = 54.0667808219178
# (751,)
# (490,)
# (506,)
# (589,)
# prueba = 54.794520547945204
# (763,)
# (445,)
# (575,)
# (553,)
# validación = 57.27739726027398
# (752,)
# (423,)
# (596,)
# (565,)
# prueba = 59.28938356164384
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (465,)
# (0,)
# (0,)
# (1871,)
# validación = 20.761986301369863
# (424,)
# (0,)
# (0,)
# (1912,)
# prueba = 22.945205479452056
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (986,)
# (140,)
# (490,)
# (720,)
# validación = 39.38356164383562
# (974,)
# (132,)
# (459,)
# (771,)
# prueba = 41.73801369863014
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (726,)
# (718,)
# (351,)
# (541,)
# validación = 58.69006849315068
# (735,)
# (695,)
# (329,)
# (577,)
# prueba = 58.81849315068494
# (628,)
# (640,)
# (542,)
# (526,)
# validación = 58.69006849315068
# (638,)
# (601,)
# (545,)
# (552,)
# prueba = 60.40239726027398
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1422,)
# (400,)
# (0,)
# (514,)
# validación = 45.07705479452055
# (1391,)
# (401,)
# (0,)
# (544,)
# prueba = 45.63356164383562
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (630,)
# (571,)
# (602,)
# (533,)
# validación = 64.6832191780822
# (637,)
# (581,)
# (555,)
# (563,)
# prueba = 67.12328767123287
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095

# %% [markdown]
# mejor = [35, 28, 21, 14, 7]

# %%
redes = []

for i in [63, 56, 49, 42, 35, 28, 21, 14]:
    
    redes.append(i)
    
    r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

    iteraciones = [10, 50, 100, 200, 300, 400, 500]
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.title("tipo de red: {}".format(redes))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (1499,)
# (391,)
# (127,)
# (319,)
# validación = 29.28082191780822
# (1517,)
# (358,)
# (147,)
# (314,)
# prueba = 30.00856164383562
# (726,)
# (365,)
# (607,)
# (638,)
# validación = 41.43835616438356
# (716,)
# (370,)
# (629,)
# (621,)
# prueba = 42.03767123287671
# (675,)
# (520,)
# (508,)
# (633,)
# validación = 48.63013698630137
# (663,)
# (508,)
# (524,)
# (641,)
# prueba = 47.94520547945205
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# (658,)
# (501,)
# (571,)
# (606,)
# validación = 45.71917808219178
# (637,)
# (480,)
# (561,)
# (658,)
# prueba = 45.93321917808219
# (661,)
# (507,)
# (546,)
# (622,)
# validación = 45.33390410958904
# (645,)
# (505,)
# (597,)
# (589,)
# prueba = 45.07705479452055
# (603,)
# (581,)
# (569,)
# (583,)
# validación = 43.10787671232877
# (627,)
# (553,)
# (518,)
# (638,)
# prueba = 42.80821917808219
# (653,)
# (521,)
# (589,)
# (573,)
# validación = 48.33047945205479
# (636,)
# (526,)
# (584,)
# (590,)
# prueba = 49.74315068493151
# (463,)
# (801,)
# (355,)
# (717,)
# validación = 27.26883561643836
# (458,)
# (757,)
# (359,)
# (762,)
# prueba = 28.5958904109589
# (732,)
# (380,)
# (429,)
# (795,)
# validación = 33.30479452054795
# (697,)
# (379,)
# (438,)
# (822,)
# prueba = 34.97431506849315
# (588,)
# (321,)
# (662,)
# (765,)
# validación = 55.22260273972602
# (575,)
# (300,)
# (650,)
# (811,)
# prueba = 52.31164383561644
# (625,)
# (558,)
# (586,)
# (567,)
# validación = 76.58390410958904
# (607,)
# (518,)
# (610,)
# (601,)
# prueba = 75.89897260273972
# (627,)
# (557,)
# (587,)
# (565,)
# validación = 74.0154109589041
# (601,)
# (550,)
# (585,)
# (600,)
# prueba = 74.31506849315068
# (577,)
# (576,)
# (604,)
# (579,)
# validación = 72.98801369863014
# (608,)
# (557,)
# (603,)
# (568,)
# prueba = 73.20205479452055
# (602,)
# (544,)
# (633,)
# (557,)
# validación = 72.6027397260274
# (578,)
# (545,)
# (609,)
# (604,)
# prueba = 72.04623287671232
# (0,)
# (64,)
# (405,)
# (1867,)
# validación = 23.501712328767123
# (0,)
# (69,)
# (407,)
# (1860,)
# prueba = 24.101027397260275
# (749,)
# (831,)
# (60,)
# (696,)
# validación = 27.78253424657534
# (729,)
# (794,)
# (69,)
# (744,)
# prueba = 29.96575342465753
# (839,)
# (115,)
# (401,)
# (981,)
# validación = 35.70205479452055
# (813,)
# (79,)
# (434,)
# (1010,)
# prueba = 36.72945205479452
# (653,)
# (652,)
# (488,)
# (543,)
# validación = 65.3681506849315
# (593,)
# (651,)
# (524,)
# (568,)
# prueba = 64.51198630136986
# (589,)
# (566,)
# (633,)
# (548,)
# validación = 73.11643835616438
# (573,)
# (521,)
# (657,)
# (585,)
# prueba = 76.4554794520548
# (587,)
# (569,)
# (613,)
# (567,)
# validación = 71.70376712328768
# (578,)
# (584,)
# (583,)
# (591,)
# prueba = 72.04623287671232
# (589,)
# (588,)
# (594,)
# (565,)
# validación = 71.70376712328768
# (539,)
# (596,)
# (606,)
# (595,)
# prueba = 68.45034246575342
# (2336,)
# (0,)
# (0,)
# (0,)
# validación = 24.700342465753426
# (2336,)
# (0,)
# (0,)
# (0,)
# prueba = 24.44349315068493
# (643,)
# (1693,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (687,)
# (1649,)
# (0,)
# (0,)
# prueba = 27.22602739726027
# (910,)
# (520,)
# (411,)
# (495,)
# validación = 32.40582191780822
# (841,)
# (486,)
# (448,)
# (561,)
# prueba = 37.11472602739726
# (762,)
# (498,)
# (479,)
# (597,)
# validación = 46.78938356164384
# (760,)
# (466,)
# (486,)
# (624,)
# prueba = 50.12842465753424
# (620,)
# (523,)
# (608,)
# (585,)
# validación = 67.46575342465754
# (599,)
# (556,)
# (567,)
# (614,)
# prueba = 68.4931506849315
# (615,)
# (590,)
# (581,)
# (550,)
# validación = 71.48972602739725
# (594,)
# (525,)
# (621,)
# (596,)
# prueba = 72.51712328767124
# (590,)
# (588,)
# (603,)
# (555,)
# validación = 77.44006849315068
# (588,)
# (526,)
# (624,)
# (598,)
# prueba = 76.75513698630137
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (2331,)
# (0,)
# (0,)
# (5,)
# validación = 24.914383561643834
# (2323,)
# (2,)
# (0,)
# (11,)
# prueba = 25.0
# (0,)
# (0,)
# (1761,)
# (575,)
# validación = 38.27054794520548
# (0,)
# (0,)
# (1745,)
# (591,)
# prueba = 39.81164383561644
# (734,)
# (816,)
# (216,)
# (570,)
# validación = 61.215753424657535
# (705,)
# (826,)
# (211,)
# (594,)
# prueba = 62.071917808219176
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2237,)
# (0,)
# (99,)
# validación = 27.95376712328767
# (0,)
# (2219,)
# (0,)
# (117,)
# prueba = 27.825342465753423
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095

# %% [markdown]
# mejor = [63, 56, 49, 42]

# %%
redes = [63]

for i in [42, 35, 21, 7]:
    
    redes.append(i)
    
    r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

    iteraciones = [10, 50, 100, 200, 300, 400, 500]
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.title("tipo de red: {}".format(redes))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (537,)
# (797,)
# (402,)
# (600,)
# validación = 26.41267123287671
# (559,)
# (798,)
# (402,)
# (577,)
# prueba = 28.16780821917808
# (772,)
# (203,)
# (298,)
# (1063,)
# validación = 37.20034246575342
# (767,)
# (194,)
# (335,)
# (1040,)
# prueba = 39.46917808219178
# (726,)
# (528,)
# (388,)
# (694,)
# validación = 52.01198630136986
# (680,)
# (532,)
# (373,)
# (751,)
# prueba = 53.51027397260274
# (624,)
# (506,)
# (616,)
# (590,)
# validación = 73.0736301369863
# (631,)
# (489,)
# (612,)
# (604,)
# prueba = 72.77397260273972
# (613,)
# (557,)
# (614,)
# (552,)
# validación = 73.97260273972603
# (575,)
# (552,)
# (599,)
# (610,)
# prueba = 74.78595890410958
# (629,)
# (520,)
# (626,)
# (561,)
# validación = 70.33390410958904
# (595,)
# (510,)
# (620,)
# (611,)
# prueba = 70.59075342465754
# (645,)
# (539,)
# (584,)
# (568,)
# validación = 72.77397260273972
# (620,)
# (506,)
# (615,)
# (595,)
# prueba = 72.04623287671232
# (0,)
# (2335,)
# (1,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2335,)
# (1,)
# (0,)
# prueba = 24.486301369863014
# (773,)
# (878,)
# (87,)
# (598,)
# validación = 26.9263698630137
# (741,)
# (894,)
# (91,)
# (610,)
# prueba = 30.00856164383562
# (997,)
# (683,)
# (3,)
# (653,)
# validación = 27.61130136986301
# (1030,)
# (684,)
# (6,)
# (616,)
# prueba = 27.95376712328767
# (740,)
# (440,)
# (580,)
# (576,)
# validación = 59.28938356164384
# (767,)
# (366,)
# (597,)
# (606,)
# prueba = 61.08732876712328
# (632,)
# (457,)
# (642,)
# (605,)
# validación = 68.06506849315068
# (563,)
# (474,)
# (665,)
# (634,)
# prueba = 68.32191780821918
# (622,)
# (576,)
# (594,)
# (544,)
# validación = 76.96917808219177
# (615,)
# (546,)
# (588,)
# (587,)
# prueba = 76.15582191780823
# (586,)
# (583,)
# (606,)
# (561,)
# validación = 67.16609589041096
# (560,)
# (546,)
# (612,)
# (618,)
# prueba = 66.69520547945206
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1113,)
# (158,)
# (46,)
# (1019,)
# validación = 24.914383561643834
# (1183,)
# (146,)
# (47,)
# (960,)
# prueba = 26.32705479452055
# (299,)
# (0,)
# (1188,)
# (849,)
# validación = 33.60445205479452
# (283,)
# (0,)
# (1170,)
# (883,)
# prueba = 35.1027397260274
# (810,)
# (628,)
# (288,)
# (610,)
# validación = 54.3236301369863
# (794,)
# (638,)
# (261,)
# (643,)
# prueba = 56.33561643835616
# (660,)
# (557,)
# (575,)
# (544,)
# validación = 65.8818493150685
# (624,)
# (553,)
# (580,)
# (579,)
# prueba = 67.5513698630137
# (589,)
# (557,)
# (628,)
# (562,)
# validación = 64.25513698630137
# (606,)
# (523,)
# (603,)
# (604,)
# prueba = 65.06849315068493
# (634,)
# (548,)
# (580,)
# (574,)
# validación = 71.1472602739726
# (638,)
# (529,)
# (555,)
# (614,)
# prueba = 71.27568493150685
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (25,)
# (573,)
# (1071,)
# (667,)
# validación = 43.2791095890411
# (29,)
# (598,)
# (1035,)
# (674,)
# prueba = 44.09246575342466
# (898,)
# (636,)
# (219,)
# (583,)
# validación = 54.66609589041096
# (924,)
# (605,)
# (205,)
# (602,)
# prueba = 57.1917808219178
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1338,)
# (182,)
# (263,)
# (553,)
# validación = 49.05821917808219
# (1323,)
# (177,)
# (264,)
# (572,)
# prueba = 50.81335616438356

# %%
redes = [63]

for i in [49, 35, 21, 7]:
    
    redes.append(i)
    
    r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

    iteraciones = [10, 50, 100, 200, 300, 400, 500]
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0.01, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.title("tipo de red: {}".format(redes))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (677,)
# (870,)
# (51,)
# (738,)
# validación = 24.315068493150687
# (702,)
# (782,)
# (70,)
# (782,)
# prueba = 24.914383561643834
# (678,)
# (737,)
# (287,)
# (634,)
# validación = 34.50342465753425
# (711,)
# (678,)
# (279,)
# (668,)
# prueba = 34.67465753424658
# (641,)
# (580,)
# (474,)
# (641,)
# validación = 54.75171232876712
# (619,)
# (573,)
# (462,)
# (682,)
# prueba = 56.207191780821915
# (611,)
# (522,)
# (630,)
# (573,)
# validación = 69.77739726027397
# (570,)
# (539,)
# (609,)
# (618,)
# prueba = 72.21746575342466
# (624,)
# (580,)
# (561,)
# (571,)
# validación = 71.53253424657534
# (610,)
# (543,)
# (582,)
# (601,)
# prueba = 74.0582191780822
# (616,)
# (552,)
# (601,)
# (567,)
# validación = 73.84417808219177
# (566,)
# (542,)
# (614,)
# (614,)
# prueba = 72.30308219178082
# (608,)
# (561,)
# (595,)
# (572,)
# validación = 71.10445205479452
# (578,)
# (544,)
# (613,)
# (601,)
# prueba = 71.875
# (223,)
# (2065,)
# (0,)
# (48,)
# validación = 25.59931506849315
# (252,)
# (2022,)
# (0,)
# (62,)
# prueba = 24.65753424657534
# (832,)
# (636,)
# (410,)
# (458,)
# validación = 29.28082191780822
# (818,)
# (616,)
# (420,)
# (482,)
# prueba = 32.23458904109589
# (640,)
# (673,)
# (341,)
# (682,)
# validación = 41.60958904109589
# (606,)
# (684,)
# (344,)
# (702,)
# prueba = 42.38013698630137
# (594,)
# (556,)
# (615,)
# (571,)
# validación = 67.97945205479452
# (609,)
# (499,)
# (632,)
# (596,)
# prueba = 67.67979452054794
# (612,)
# (572,)
# (596,)
# (556,)
# validación = 69.77739726027397
# (613,)
# (571,)
# (583,)
# (569,)
# prueba = 70.29109589041096
# (605,)
# (587,)
# (573,)
# (571,)
# validación = 71.83219178082192
# (618,)
# (528,)
# (588,)
# (602,)
# prueba = 71.6181506849315
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: divide by zero encountered in log
#   s1 = y * np.log(h)
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: invalid value encountered in multiply
#   s1 = y * np.log(h)
# (607,)
# (574,)
# (589,)
# (566,)
# validación = 74.0582191780822
# (595,)
# (560,)
# (568,)
# (613,)
# prueba = 74.31506849315068
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (1465,)
# (0,)
# (871,)
# validación = 24.871575342465754
# (0,)
# (1484,)
# (0,)
# (852,)
# prueba = 26.070205479452053
# (751,)
# (276,)
# (599,)
# (710,)
# validación = 43.66438356164384
# (734,)
# (268,)
# (607,)
# (727,)
# prueba = 44.99143835616438
# (1027,)
# (610,)
# (121,)
# (578,)
# validación = 53.98116438356164
# (999,)
# (586,)
# (132,)
# (619,)
# prueba = 55.47945205479452
# (626,)
# (552,)
# (585,)
# (573,)
# validación = 68.0222602739726
# (629,)
# (558,)
# (544,)
# (605,)
# prueba = 68.10787671232876
# (611,)
# (582,)
# (591,)
# (552,)
# validación = 67.97945205479452
# (621,)
# (569,)
# (570,)
# (576,)
# prueba = 70.11986301369863
# (598,)
# (563,)
# (611,)
# (564,)
# validación = 72.51712328767124
# (576,)
# (573,)
# (606,)
# (581,)
# prueba = 71.57534246575342
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (954,)
# (1382,)
# (0,)
# (0,)
# validación = 26.36986301369863
# (964,)
# (1372,)
# (0,)
# (0,)
# prueba = 25.59931506849315
# (1015,)
# (656,)
# (72,)
# (593,)
# validación = 50.64212328767124
# (1015,)
# (648,)
# (63,)
# (610,)
# prueba = 50.34246575342466
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (835,)
# (719,)
# (204,)
# (578,)
# validación = 58.090753424657535
# (823,)
# (694,)
# (211,)
# (608,)
# prueba = 60.273972602739725
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095

# %%
redes = [56, 49, 35]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (1,)
# (1570,)
# (0,)
# (765,)
# validación = 25.256849315068493
# (1,)
# (1554,)
# (0,)
# (781,)
# prueba = 24.65753424657534
# (572,)
# (690,)
# (200,)
# (874,)
# validación = 28.339041095890412
# (561,)
# (669,)
# (220,)
# (886,)
# prueba = 29.88013698630137
# (142,)
# (599,)
# (642,)
# (953,)
# validación = 38.14212328767123
# (142,)
# (555,)
# (628,)
# (1011,)
# prueba = 39.4263698630137
# (666,)
# (474,)
# (625,)
# (571,)
# validación = 64.98287671232876
# (656,)
# (464,)
# (625,)
# (591,)
# prueba = 66.52397260273972
# (602,)
# (556,)
# (612,)
# (566,)
# validación = 69.4777397260274
# (589,)
# (531,)
# (608,)
# (608,)
# prueba = 66.73801369863014
# (578,)
# (566,)
# (608,)
# (584,)
# validación = 72.55993150684932
# (562,)
# (561,)
# (610,)
# (603,)
# prueba = 72.6027397260274
# (598,)
# (599,)
# (577,)
# (562,)
# validación = 66.8236301369863
# (560,)
# (577,)
# (584,)
# (615,)
# prueba = 67.12328767123287

# %%
redes = [63, 49, 42]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (76,)
# (2074,)
# (0,)
# (186,)
# validación = 27.52568493150685
# (105,)
# (2019,)
# (0,)
# (212,)
# prueba = 27.26883561643836
# (630,)
# (41,)
# (1098,)
# (567,)
# validación = 31.25
# (584,)
# (32,)
# (1111,)
# (609,)
# prueba = 31.07876712328767
# (700,)
# (286,)
# (682,)
# (668,)
# validación = 46.57534246575342
# (709,)
# (260,)
# (674,)
# (693,)
# prueba = 46.446917808219176
# (622,)
# (516,)
# (635,)
# (563,)
# validación = 68.23630136986301
# (619,)
# (494,)
# (615,)
# (608,)
# prueba = 67.8082191780822
# (588,)
# (510,)
# (674,)
# (564,)
# validación = 73.67294520547945
# (620,)
# (444,)
# (655,)
# (617,)
# prueba = 73.63013698630137
# (628,)
# (553,)
# (591,)
# (564,)
# validación = 74.35787671232876
# (600,)
# (556,)
# (583,)
# (597,)
# prueba = 74.65753424657534
# (614,)
# (627,)
# (534,)
# (561,)
# validación = 67.93664383561644
# (606,)
# (547,)
# (592,)
# (591,)
# prueba = 67.8082191780822

# %%
redes = [56, 49, 42]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (708,)
# (721,)
# (407,)
# (500,)
# validación = 29.88013698630137
# (719,)
# (734,)
# (395,)
# (488,)
# prueba = 29.06678082191781
# (655,)
# (269,)
# (710,)
# (702,)
# validación = 46.446917808219176
# (684,)
# (232,)
# (661,)
# (759,)
# prueba = 47.64554794520548
# (675,)
# (489,)
# (590,)
# (582,)
# validación = 62.5
# (656,)
# (491,)
# (566,)
# (623,)
# prueba = 64.6832191780822
# (611,)
# (526,)
# (641,)
# (558,)
# validación = 72.68835616438356
# (584,)
# (516,)
# (647,)
# (589,)
# prueba = 72.55993150684932
# (588,)
# (572,)
# (605,)
# (571,)
# validación = 70.29109589041096
# (549,)
# (549,)
# (620,)
# (618,)
# prueba = 70.59075342465754
# (576,)
# (603,)
# (599,)
# (558,)
# validación = 70.29109589041096
# (552,)
# (566,)
# (629,)
# (589,)
# prueba = 71.96061643835617

# %%
redes = [63, 49, 42, 35]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1181,)
# (60,)
# (1,)
# (1094,)
# validación = 24.700342465753426
# (1189,)
# (68,)
# (3,)
# (1076,)
# prueba = 27.31164383561644
# (639,)
# (581,)
# (607,)
# (509,)
# validación = 36.72945205479452
# (600,)
# (612,)
# (589,)
# (535,)
# prueba = 39.12671232876712
# (748,)
# (568,)
# (456,)
# (564,)
# validación = 59.203767123287676
# (729,)
# (583,)
# (417,)
# (607,)
# prueba = 57.705479452054796
# (636,)
# (564,)
# (562,)
# (574,)
# validación = 69.99143835616438
# (604,)
# (550,)
# (583,)
# (599,)
# prueba = 69.34931506849315
# (584,)
# (595,)
# (600,)
# (557,)
# validación = 70.33390410958904
# (597,)
# (529,)
# (614,)
# (596,)
# prueba = 71.36130136986301
# (628,)
# (583,)
# (568,)
# (557,)
# validación = 72.6027397260274
# (589,)
# (534,)
# (606,)
# (607,)
# prueba = 70.84760273972603

# %%
redes = [63, 56, 49, 42]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1324,)
# (0,)
# (180,)
# (832,)
# validación = 25.214041095890412
# (1272,)
# (0,)
# (173,)
# (891,)
# prueba = 27.26883561643836
# (1060,)
# (7,)
# (3,)
# (1266,)
# validación = 25.642123287671232
# (1070,)
# (5,)
# (8,)
# (1253,)
# prueba = 27.482876712328768
# (694,)
# (470,)
# (546,)
# (626,)
# validación = 54.15239726027398
# (664,)
# (456,)
# (539,)
# (677,)
# prueba = 54.62328767123288
# (629,)
# (554,)
# (581,)
# (572,)
# validación = 71.83219178082192
# (637,)
# (511,)
# (593,)
# (595,)
# prueba = 72.6027397260274
# (563,)
# (601,)
# (616,)
# (556,)
# validación = 71.875
# (588,)
# (541,)
# (617,)
# (590,)
# prueba = 70.59075342465754
# (575,)
# (567,)
# (642,)
# (552,)
# validación = 68.36472602739725
# (578,)
# (568,)
# (610,)
# (580,)
# prueba = 71.44691780821918

# %%
redes = [63, 42, 35, 7]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (773,)
# (0,)
# (1,)
# (1562,)
# validación = 27.18321917808219
# (786,)
# (0,)
# (0,)
# (1550,)
# prueba = 29.152397260273972
# (560,)
# (0,)
# (839,)
# (937,)
# validación = 39.59760273972603
# (577,)
# (0,)
# (792,)
# (967,)
# prueba = 40.45376712328767
# (718,)
# (610,)
# (346,)
# (662,)
# validación = 52.3972602739726
# (709,)
# (620,)
# (346,)
# (661,)
# prueba = 52.26883561643836
# (703,)
# (816,)
# (246,)
# (571,)
# validación = 59.332191780821915
# (681,)
# (805,)
# (259,)
# (591,)
# prueba = 58.34760273972602
# (580,)
# (675,)
# (513,)
# (568,)
# validación = 62.7568493150685
# (589,)
# (630,)
# (510,)
# (607,)
# prueba = 62.714041095890416
# (614,)
# (537,)
# (621,)
# (564,)
# validación = 60.53082191780822
# (631,)
# (508,)
# (593,)
# (604,)
# prueba = 62.88527397260274

# %%
redes = [63, 42, 28, 7]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (707,)
# (513,)
# (11,)
# (1105,)
# validación = 26.79794520547945
# (751,)
# (492,)
# (16,)
# (1077,)
# prueba = 29.96575342465753
# (717,)
# (1061,)
# (55,)
# (503,)
# validación = 35.44520547945205
# (717,)
# (1027,)
# (64,)
# (528,)
# prueba = 37.28595890410959
# (1030,)
# (106,)
# (637,)
# (563,)
# validación = 57.705479452054796
# (995,)
# (116,)
# (639,)
# (586,)
# prueba = 58.04794520547946
# (674,)
# (307,)
# (768,)
# (587,)
# validación = 62.542808219178085
# (624,)
# (329,)
# (773,)
# (610,)
# prueba = 61.34417808219178
# (622,)
# (528,)
# (616,)
# (570,)
# validación = 71.23287671232876
# (638,)
# (499,)
# (591,)
# (608,)
# prueba = 71.74657534246576
# (598,)
# (499,)
# (666,)
# (573,)
# validación = 57.49143835616438
# (588,)
# (466,)
# (689,)
# (593,)
# prueba = 58.4332191780822

# %%
redes = [63, 42, 21, 7]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

iteraciones = [10, 50, 100, 200, 300, 400, 500]
validaciones = []
pruebas = []

for i in range(len(iteraciones)):
    p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, 0, iteraciones[i], INIT_EPSILON)
    validaciones.append(p1)
    pruebas.append(p2)
    
plt.figure()
plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (1365,)
# (0,)
# (971,)
# validación = 25.55650684931507
# (0,)
# (1374,)
# (0,)
# (962,)
# prueba = 27.482876712328768
# (484,)
# (0,)
# (1314,)
# (538,)
# validación = 30.39383561643836
# (463,)
# (0,)
# (1381,)
# (492,)
# prueba = 31.977739726027398
# (261,)
# (711,)
# (799,)
# (565,)
# validación = 54.3236301369863
# (238,)
# (675,)
# (822,)
# (601,)
# prueba = 54.794520547945204
# (629,)
# (548,)
# (587,)
# (572,)
# validación = 66.26712328767124
# (622,)
# (495,)
# (617,)
# (602,)
# prueba = 65.625
# (994,)
# (604,)
# (170,)
# (568,)
# validación = 55.86472602739726
# (981,)
# (550,)
# (185,)
# (620,)
# prueba = 56.292808219178085
# (954,)
# (97,)
# (693,)
# (592,)
# validación = 59.974315068493155
# (957,)
# (87,)
# (687,)
# (605,)
# prueba = 59.46061643835616

# %%
redes = [63, 56, 49, 42]
Lambdas = [0, 0.0001, 0.001, 0.01, 0.1, 1]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

for L in Lambdas:

    iteraciones = [10, 50, 100, 200, 300, 400, 500]
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.title("Lambda: {}".format(L))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (65,)
# (1021,)
# (0,)
# (1250,)
# validación = 26.1986301369863
# (56,)
# (1028,)
# (0,)
# (1252,)
# prueba = 25.04280821917808
# (925,)
# (1008,)
# (0,)
# (403,)
# validación = 32.19178082191781
# (931,)
# (975,)
# (0,)
# (430,)
# prueba = 32.23458904109589
# (666,)
# (589,)
# (472,)
# (609,)
# validación = 52.140410958904106
# (637,)
# (560,)
# (517,)
# (622,)
# prueba = 53.51027397260274
# (556,)
# (565,)
# (647,)
# (568,)
# validación = 72.04623287671232
# (574,)
# (543,)
# (597,)
# (622,)
# prueba = 71.78938356164383
# (626,)
# (586,)
# (555,)
# (569,)
# validación = 73.88698630136986
# (622,)
# (569,)
# (556,)
# (589,)
# prueba = 76.15582191780823
# (605,)
# (585,)
# (581,)
# (565,)
# validación = 68.40753424657534
# (610,)
# (544,)
# (578,)
# (604,)
# prueba = 70.2054794520548
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (0,)
# (1908,)
# (428,)
# validación = 25.12842465753425
# (0,)
# (0,)
# (1927,)
# (409,)
# prueba = 25.81335616438356
# (332,)
# (11,)
# (1586,)
# (407,)
# validación = 32.79109589041096
# (350,)
# (7,)
# (1559,)
# (420,)
# prueba = 34.332191780821915
# (810,)
# (740,)
# (109,)
# (677,)
# validación = 47.94520547945205
# (771,)
# (739,)
# (114,)
# (712,)
# prueba = 50.4708904109589
# (676,)
# (599,)
# (466,)
# (595,)
# validación = 63.05650684931506
# (653,)
# (587,)
# (495,)
# (601,)
# prueba = 64.25513698630137
# (622,)
# (578,)
# (568,)
# (568,)
# validación = 70.46232876712328
# (624,)
# (550,)
# (574,)
# (588,)
# prueba = 70.71917808219177
# (598,)
# (580,)
# (581,)
# (577,)
# validación = 72.08904109589042
# (602,)
# (555,)
# (578,)
# (601,)
# prueba = 72.1318493150685
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (739,)
# (1272,)
# (0,)
# (325,)
# validación = 26.583904109589042
# (709,)
# (1282,)
# (0,)
# (345,)
# prueba = 25.12842465753425
# (1914,)
# (91,)
# (36,)
# (295,)
# validación = 29.92294520547945
# (1912,)
# (73,)
# (32,)
# (319,)
# prueba = 30.30821917808219
# (644,)
# (767,)
# (360,)
# (565,)
# validación = 55.13698630136986
# (654,)
# (708,)
# (386,)
# (588,)
# prueba = 56.33561643835616
# (749,)
# (488,)
# (540,)
# (559,)
# validación = 63.99828767123288
# (733,)
# (458,)
# (539,)
# (606,)
# prueba = 63.61301369863014
# (600,)
# (561,)
# (596,)
# (579,)
# validación = 65.53938356164383
# (577,)
# (519,)
# (627,)
# (613,)
# prueba = 66.3527397260274
# (592,)
# (537,)
# (660,)
# (547,)
# validación = 71.66095890410958
# (600,)
# (511,)
# (637,)
# (588,)
# prueba = 72.6027397260274
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (12,)
# (647,)
# (687,)
# (990,)
# validación = 26.24143835616438
# (11,)
# (629,)
# (717,)
# (979,)
# prueba = 27.52568493150685
# (1144,)
# (380,)
# (0,)
# (812,)
# validación = 36.00171232876712
# (1149,)
# (384,)
# (0,)
# (803,)
# prueba = 38.09931506849315
# (644,)
# (586,)
# (521,)
# (585,)
# validación = 55.179794520547944
# (610,)
# (567,)
# (542,)
# (617,)
# prueba = 57.36301369863014
# (701,)
# (571,)
# (479,)
# (585,)
# validación = 61.5582191780822
# (731,)
# (534,)
# (456,)
# (615,)
# prueba = 62.2431506849315
# (647,)
# (536,)
# (587,)
# (566,)
# validación = 71.57534246575342
# (618,)
# (537,)
# (590,)
# (591,)
# prueba = 71.36130136986301
# (573,)
# (609,)
# (600,)
# (554,)
# validación = 69.7345890410959
# (559,)
# (571,)
# (619,)
# (587,)
# prueba = 70.24828767123287
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (904,)
# (437,)
# (425,)
# (570,)
# validación = 28.039383561643838
# (874,)
# (422,)
# (443,)
# (597,)
# prueba = 29.152397260273972
# (871,)
# (381,)
# (12,)
# (1072,)
# validación = 27.95376712328767
# (861,)
# (328,)
# (19,)
# (1128,)
# prueba = 29.666095890410958
# (382,)
# (1405,)
# (2,)
# (547,)
# validación = 45.6763698630137
# (405,)
# (1346,)
# (0,)
# (585,)
# prueba = 46.70376712328767
# (690,)
# (540,)
# (545,)
# (561,)
# validación = 66.73801369863014
# (695,)
# (518,)
# (530,)
# (593,)
# prueba = 68.23630136986301
# (623,)
# (618,)
# (537,)
# (558,)
# validación = 72.26027397260275
# (631,)
# (599,)
# (507,)
# (599,)
# prueba = 73.8013698630137
# (1380,)
# (337,)
# (184,)
# (435,)
# validación = 31.892123287671232
# (1302,)
# (340,)
# (226,)
# (468,)
# prueba = 33.98972602739726
# (0,)
# (0,)
# (0,)
# (2336,)
# validación = 23.8013698630137
# (0,)
# (0,)
# (0,)
# (2336,)
# prueba = 25.51369863013699
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095

# %%
redes = [63, 56, 49, 42]
Lambdas = [0.001]

r = red_neuronal(len(redes), redes, 0.12, Ex.shape[1], 4)

for L in Lambdas:

    iteraciones = [50, 100, 300, 500, 700, 1000, 1300, 1500, 1700, 2000]
    validaciones = []
    pruebas = []

    for i in range(len(iteraciones)):
        p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
        validaciones.append(p1)
        pruebas.append(p2)

    plt.figure()
    plt.title("Lambda: {}".format(L))
    plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
    plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
    plt.show()
# Out:
# (314,)
# (1147,)
# (0,)
# (875,)
# validación = 26.62671232876712
# (300,)
# (1161,)
# (1,)
# (874,)
# prueba = 26.75513698630137
# (712,)
# (244,)
# (855,)
# (525,)
# validación = 32.87671232876712
# (695,)
# (256,)
# (827,)
# (558,)
# prueba = 33.26198630136986
# (629,)
# (487,)
# (662,)
# (558,)
# validación = 69.04965753424658
# (573,)
# (470,)
# (690,)
# (603,)
# prueba = 68.83561643835617
# (601,)
# (580,)
# (597,)
# (558,)
# validación = 69.13527397260275
# (569,)
# (570,)
# (607,)
# (590,)
# prueba = 69.39212328767124
# (599,)
# (592,)
# (602,)
# (543,)
# validación = 70.71917808219177
# (601,)
# (556,)
# (605,)
# (574,)
# prueba = 71.36130136986301
# (585,)
# (596,)
# (582,)
# (573,)
# validación = 69.86301369863014
# (550,)
# (582,)
# (604,)
# (600,)
# prueba = 69.6917808219178
# (590,)
# (589,)
# (585,)
# (572,)
# validación = 73.50171232876713
# (601,)
# (549,)
# (576,)
# (610,)
# prueba = 73.8013698630137
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# (601,)
# (567,)
# (598,)
# (570,)
# validación = 70.37671232876713
# (595,)
# (525,)
# (610,)
# (606,)
# prueba = 69.7345890410959
# (578,)
# (598,)
# (588,)
# (572,)
# validación = 71.74657534246576
# (575,)
# (562,)
# (638,)
# (561,)
# prueba = 72.94520547945206
# (598,)
# (554,)
# (628,)
# (556,)
# validación = 69.99143835616438
# (552,)
# (591,)
# (602,)
# (591,)
# prueba = 71.74657534246576

# %%
redes = [63, 56, 49, 42, 35, 28, 21, 14, 7]
Lambdas = [0.001]

for r1 in redes:
    
    for r2 in redes:
        
        for r3 in redes:
            
            for r4 in redes:
                
                for r5 in redes:

                    r = red_neuronal(5, [r1, r2, r3, r4, r5], 0.12, Ex.shape[1], 4)

                    for L in Lambdas:

                        iteraciones = [50, 100, 300, 500]
                        validaciones = []
                        pruebas = []

                        for i in range(len(iteraciones)):
                            p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
                            validaciones.append(p1)
                            pruebas.append(p2)

                        plt.figure()
                        plt.title("red: {}".format([r1, r2, r3, r4, r5]))
                        plt.plot(np.array(iteraciones), np.array(validaciones), label = 'validaciones' , Color = 'red')
                        plt.plot(np.array(iteraciones), np.array(pruebas), label = 'pruebas' , Color = 'blue')
                        plt.show()
# Out:
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (135,)
# (0,)
# (2201,)
# validación = 22.559931506849313
# (0,)
# (130,)
# (0,)
# (2206,)
# prueba = 24.315068493150687
# (827,)
# (853,)
# (65,)
# (591,)
# validación = 57.705479452054796
# (812,)
# (836,)
# (82,)
# (606,)
# prueba = 57.534246575342465
# (831,)
# (884,)
# (37,)
# (584,)
# validación = 54.109589041095894
# (850,)
# (833,)
# (39,)
# (614,)
# prueba = 54.66609589041096
# (621,)
# (10,)
# (932,)
# (773,)
# validación = 27.054794520547947
# (649,)
# (8,)
# (952,)
# (727,)
# prueba = 28.46746575342466
# (267,)
# (1205,)
# (0,)
# (864,)
# validación = 27.054794520547947
# (282,)
# (1197,)
# (0,)
# (857,)
# prueba = 28.039383561643838
# (671,)
# (625,)
# (454,)
# (586,)
# validación = 59.76027397260274
# (662,)
# (658,)
# (404,)
# (612,)
# prueba = 60.70205479452054
# (635,)
# (534,)
# (585,)
# (582,)
# validación = 70.50513698630137
# (581,)
# (503,)
# (656,)
# (596,)
# prueba = 71.4041095890411
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1062,)
# (515,)
# (189,)
# (570,)
# validación = 49.91438356164384
# (1050,)
# (489,)
# (200,)
# (597,)
# prueba = 49.5291095890411
# (609,)
# (559,)
# (574,)
# (594,)
# validación = 71.875
# (599,)
# (558,)
# (593,)
# (586,)
# prueba = 72.00342465753424
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2332,)
# (0,)
# (4,)
# validación = 25.85616438356164
# (0,)
# (2334,)
# (0,)
# (2,)
# prueba = 24.529109589041095
# (801,)
# (842,)
# (152,)
# (541,)
# validación = 55.13698630136986
# (806,)
# (806,)
# (117,)
# (607,)
# prueba = 55.56506849315068
# (692,)
# (930,)
# (138,)
# (576,)
# validación = 60.61643835616438
# (657,)
# (916,)
# (149,)
# (614,)
# prueba = 61.601027397260275
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (606,)
# (586,)
# (590,)
# (554,)
# validación = 57.36301369863014
# (608,)
# (539,)
# (603,)
# (586,)
# prueba = 58.005136986301366
# (607,)
# (567,)
# (575,)
# (587,)
# validación = 66.52397260273972
# (609,)
# (545,)
# (580,)
# (602,)
# prueba = 66.73801369863014
# (0,)
# (2288,)
# (0,)
# (48,)
# validación = 26.541095890410958
# (0,)
# (2275,)
# (0,)
# (61,)
# prueba = 25.59931506849315
# (1365,)
# (0,)
# (0,)
# (971,)
# validación = 29.62328767123288
# (1356,)
# (0,)
# (0,)
# (980,)
# prueba = 29.75171232876712
# (731,)
# (705,)
# (308,)
# (592,)
# validación = 60.18835616438356
# (744,)
# (671,)
# (314,)
# (607,)
# prueba = 60.05993150684932
# (624,)
# (560,)
# (597,)
# (555,)
# validación = 62.0291095890411
# (641,)
# (525,)
# (585,)
# (585,)
# prueba = 62.15753424657534
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1,)
# (2325,)
# (0,)
# (10,)
# validación = 25.98458904109589
# (2,)
# (2326,)
# (0,)
# (8,)
# prueba = 24.65753424657534
# (820,)
# (250,)
# (672,)
# (594,)
# validación = 54.0667808219178
# (795,)
# (216,)
# (702,)
# (623,)
# prueba = 53.93835616438356
# (598,)
# (513,)
# (664,)
# (561,)
# validación = 67.03767123287672
# (604,)
# (488,)
# (650,)
# (594,)
# prueba = 65.71061643835617
# (0,)
# (0,)
# (1142,)
# (1194,)
# validación = 24.82876712328767
# (0,)
# (0,)
# (1180,)
# (1156,)
# prueba = 26.41267123287671
# (0,)
# (1821,)
# (0,)
# (515,)
# validación = 27.440068493150683
# (0,)
# (1816,)
# (0,)
# (520,)
# prueba = 25.89897260273973
# (465,)
# (1397,)
# (0,)
# (474,)
# validación = 38.18493150684932
# (477,)
# (1359,)
# (0,)
# (500,)
# prueba = 39.29794520547945
# (657,)
# (694,)
# (425,)
# (560,)
# validación = 59.589041095890416
# (621,)
# (666,)
# (439,)
# (610,)
# prueba = 59.888698630136986
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1390,)
# (365,)
# (7,)
# (574,)
# validación = 46.70376712328767
# (1366,)
# (327,)
# (11,)
# (632,)
# prueba = 47.3458904109589
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2086,)
# (0,)
# (250,)
# validación = 27.78253424657534
# (0,)
# (2096,)
# (0,)
# (240,)
# prueba = 27.31164383561644
# (0,)
# (1275,)
# (0,)
# (1061,)
# validación = 26.070205479452053
# (0,)
# (1225,)
# (0,)
# (1111,)
# prueba = 26.070205479452053
# (654,)
# (610,)
# (496,)
# (576,)
# validación = 59.417808219178085
# (656,)
# (595,)
# (486,)
# (599,)
# prueba = 60.01712328767124
# (595,)
# (438,)
# (734,)
# (569,)
# validación = 62.0291095890411
# (590,)
# (460,)
# (690,)
# (596,)
# prueba = 63.05650684931506
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (1,)
# (1577,)
# (758,)
# validación = 28.16780821917808
# (0,)
# (0,)
# (1530,)
# (806,)
# prueba = 29.88013698630137
# (60,)
# (1393,)
# (199,)
# (684,)
# validación = 35.18835616438356
# (69,)
# (1350,)
# (202,)
# (715,)
# prueba = 35.273972602739725
# (591,)
# (531,)
# (649,)
# (565,)
# validación = 63.869863013698634
# (564,)
# (514,)
# (672,)
# (586,)
# prueba = 64.94006849315068
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1648,)
# (1,)
# (0,)
# (687,)
# validación = 28.767123287671232
# (1651,)
# (5,)
# (0,)
# (680,)
# prueba = 29.580479452054792
# (861,)
# (0,)
# (826,)
# (649,)
# validación = 42.67979452054795
# (822,)
# (0,)
# (842,)
# (672,)
# prueba = 45.6763698630137
# (597,)
# (571,)
# (600,)
# (568,)
# validación = 68.79280821917808
# (586,)
# (502,)
# (636,)
# (612,)
# prueba = 68.66438356164383
# (1366,)
# (0,)
# (0,)
# (970,)
# validación = 24.914383561643834
# (1329,)
# (0,)
# (0,)
# (1007,)
# prueba = 26.36986301369863
# (542,)
# (815,)
# (0,)
# (979,)
# validación = 28.29623287671233
# (507,)
# (817,)
# (0,)
# (1012,)
# prueba = 29.92294520547945
# (917,)
# (862,)
# (7,)
# (550,)
# validación = 52.09760273972602
# (901,)
# (832,)
# (4,)
# (599,)
# prueba = 52.525684931506845
# (562,)
# (646,)
# (602,)
# (526,)
# validación = 72.77397260273972
# (536,)
# (601,)
# (604,)
# (595,)
# prueba = 73.0736301369863
# (472,)
# (1693,)
# (49,)
# (122,)
# validación = 26.96917808219178
# (445,)
# (1708,)
# (58,)
# (125,)
# prueba = 25.81335616438356
# (958,)
# (329,)
# (158,)
# (891,)
# validación = 26.41267123287671
# (936,)
# (382,)
# (141,)
# (877,)
# prueba = 27.825342465753423
# (606,)
# (608,)
# (538,)
# (584,)
# validación = 65.49657534246576
# (669,)
# (541,)
# (541,)
# (585,)
# prueba = 67.2945205479452
# (641,)
# (571,)
# (566,)
# (558,)
# validación = 74.57191780821918
# (587,)
# (549,)
# (608,)
# (592,)
# prueba = 72.55993150684932
# (22,)
# (2314,)
# (0,)
# (0,)
# validación = 25.81335616438356
# (17,)
# (2319,)
# (0,)
# (0,)
# prueba = 24.44349315068493
# (12,)
# (0,)
# (1528,)
# (796,)
# validación = 27.99657534246575
# (8,)
# (0,)
# (1566,)
# (762,)
# prueba = 28.809931506849317
# (770,)
# (743,)
# (253,)
# (570,)
# validación = 60.40239726027398
# (780,)
# (724,)
# (227,)
# (605,)
# prueba = 60.18835616438356
# (620,)
# (581,)
# (565,)
# (570,)
# validación = 66.01027397260275
# (628,)
# (493,)
# (610,)
# (605,)
# prueba = 67.85102739726028
# (6,)
# (1412,)
# (0,)
# (918,)
# validación = 26.49828767123288
# (3,)
# (1415,)
# (0,)
# (918,)
# prueba = 25.89897260273973
# (1093,)
# (0,)
# (403,)
# (840,)
# validación = 28.767123287671232
# (1058,)
# (0,)
# (373,)
# (905,)
# prueba = 29.10958904109589
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (594,)
# (591,)
# (593,)
# (558,)
# validación = 71.53253424657534
# (579,)
# (572,)
# (600,)
# (585,)
# prueba = 72.00342465753424
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (878,)
# (1131,)
# (0,)
# (327,)
# validación = 27.011986301369863
# (789,)
# (1168,)
# (1,)
# (378,)
# prueba = 27.011986301369863
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (608,)
# (670,)
# (449,)
# (609,)
# validación = 60.830479452054796
# (596,)
# (670,)
# (446,)
# (624,)
# prueba = 64.98287671232876
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (1998,)
# (0,)
# (338,)
# validación = 32.36301369863014
# (0,)
# (1983,)
# (0,)
# (353,)
# prueba = 31.20719178082192
# (631,)
# (900,)
# (238,)
# (567,)
# validación = 59.6318493150685
# (627,)
# (849,)
# (251,)
# (609,)
# prueba = 62.0291095890411
# (726,)
# (927,)
# (115,)
# (568,)
# validación = 57.40582191780822
# (704,)
# (915,)
# (109,)
# (608,)
# prueba = 58.6472602739726
# (1486,)
# (0,)
# (226,)
# (624,)
# validación = 25.51369863013699
# (1426,)
# (0,)
# (237,)
# (673,)
# prueba = 27.78253424657534
# (0,)
# (1262,)
# (327,)
# (747,)
# validación = 27.69691780821918
# (0,)
# (1229,)
# (360,)
# (747,)
# prueba = 27.56849315068493
# (687,)
# (1014,)
# (32,)
# (603,)
# validación = 60.91609589041096
# (688,)
# (983,)
# (52,)
# (613,)
# prueba = 61.429794520547944
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (51,)
# (1447,)
# (23,)
# (815,)
# validación = 24.743150684931507
# (43,)
# (1469,)
# (14,)
# (810,)
# prueba = 25.085616438356162
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (966,)
# (573,)
# (229,)
# (568,)
# validación = 53.638698630136986
# (911,)
# (610,)
# (233,)
# (582,)
# prueba = 54.3236301369863
# (925,)
# (597,)
# (223,)
# (591,)
# validación = 55.650684931506845
# (944,)
# (548,)
# (230,)
# (614,)
# prueba = 56.207191780821915
# (891,)
# (398,)
# (0,)
# (1047,)
# validación = 25.55650684931507
# (857,)
# (439,)
# (0,)
# (1040,)
# prueba = 27.61130136986301
# (1068,)
# (42,)
# (0,)
# (1226,)
# validación = 26.455479452054792
# (1031,)
# (48,)
# (0,)
# (1257,)
# prueba = 26.113013698630137
# (832,)
# (720,)
# (242,)
# (542,)
# validación = 55.650684931506845
# (790,)
# (677,)
# (268,)
# (601,)
# prueba = 55.650684931506845
# (614,)
# (591,)
# (586,)
# (545,)
# validación = 68.2791095890411
# (606,)
# (531,)
# (609,)
# (590,)
# prueba = 68.57876712328768
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (898,)
# (453,)
# (0,)
# (985,)
# validación = 25.85616438356164
# (883,)
# (417,)
# (0,)
# (1036,)
# prueba = 25.55650684931507
# (650,)
# (582,)
# (564,)
# (540,)
# validación = 62.542808219178085
# (630,)
# (566,)
# (542,)
# (598,)
# prueba = 63.27054794520548
# (610,)
# (586,)
# (578,)
# (562,)
# validación = 69.64897260273972
# (586,)
# (583,)
# (579,)
# (588,)
# prueba = 71.06164383561644
# (652,)
# (574,)
# (0,)
# (1110,)
# validación = 25.727739726027398
# (675,)
# (552,)
# (0,)
# (1109,)
# prueba = 27.31164383561644
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (719,)
# (960,)
# (61,)
# (596,)
# validación = 60.3167808219178
# (707,)
# (941,)
# (63,)
# (625,)
# prueba = 60.48801369863014
# (611,)
# (605,)
# (572,)
# (548,)
# validación = 70.80479452054794
# (608,)
# (567,)
# (581,)
# (580,)
# prueba = 73.75856164383562
# (0,)
# (1773,)
# (0,)
# (563,)
# validación = 27.95376712328767
# (0,)
# (1761,)
# (0,)
# (575,)
# prueba = 27.61130136986301
# (343,)
# (125,)
# (1110,)
# (758,)
# validación = 31.934931506849317
# (313,)
# (122,)
# (1120,)
# (781,)
# prueba = 31.7208904109589
# (1000,)
# (642,)
# (102,)
# (592,)
# validación = 55.39383561643836
# (1006,)
# (645,)
# (77,)
# (608,)
# prueba = 56.035958904109584
# (596,)
# (572,)
# (598,)
# (570,)
# validación = 69.6917808219178
# (587,)
# (502,)
# (650,)
# (597,)
# prueba = 69.6917808219178
# (565,)
# (887,)
# (0,)
# (884,)
# validación = 27.18321917808219
# (599,)
# (887,)
# (0,)
# (850,)
# prueba = 27.482876712328768
# (349,)
# (877,)
# (0,)
# (1110,)
# validación = 27.69691780821918
# (348,)
# (869,)
# (0,)
# (1119,)
# prueba = 26.88356164383562
# (1436,)
# (334,)
# (0,)
# (566,)
# validación = 49.01541095890411
# (1413,)
# (280,)
# (0,)
# (643,)
# prueba = 49.91438356164384
# (589,)
# (608,)
# (570,)
# (569,)
# validación = 64.59760273972603
# (597,)
# (600,)
# (548,)
# (591,)
# prueba = 66.05308219178082
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1441,)
# (0,)
# (0,)
# (895,)
# validación = 24.529109589041095
# (1390,)
# (0,)
# (0,)
# (946,)
# prueba = 26.669520547945208
# (622,)
# (846,)
# (308,)
# (560,)
# validación = 59.24657534246576
# (638,)
# (799,)
# (302,)
# (597,)
# prueba = 60.95890410958904
# (581,)
# (416,)
# (762,)
# (577,)
# validación = 63.05650684931506
# (590,)
# (423,)
# (704,)
# (619,)
# prueba = 63.65582191780822
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (2106,)
# (0,)
# (0,)
# (230,)
# validación = 29.10958904109589
# (2068,)
# (0,)
# (0,)
# (268,)
# prueba = 29.40924657534247
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (626,)
# (658,)
# (21,)
# (1031,)
# validación = 24.18664383561644
# (654,)
# (645,)
# (26,)
# (1011,)
# prueba = 25.34246575342466
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (342,)
# (787,)
# (668,)
# (539,)
# validación = 55.13698630136986
# (348,)
# (717,)
# (674,)
# (597,)
# prueba = 56.464041095890416
# (583,)
# (534,)
# (636,)
# (583,)
# validación = 63.35616438356164
# (542,)
# (505,)
# (684,)
# (605,)
# prueba = 62.5
# (24,)
# (1028,)
# (0,)
# (1284,)
# validación = 24.529109589041095
# (36,)
# (1012,)
# (0,)
# (1288,)
# prueba = 24.44349315068493
# (1664,)
# (46,)
# (0,)
# (626,)
# validación = 25.4708904109589
# (1593,)
# (64,)
# (0,)
# (679,)
# prueba = 27.097602739726028
# D:\UNI\3ºAño\Notebook\Proyecto AA\fun_basicas.py:4: RuntimeWarning: overflow encountered in exp
#   sigmoide = 1 / (1 + np.exp(-Z))
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: divide by zero encountered in log
#   s1 = y * np.log(h)
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py:63: RuntimeWarning: invalid value encountered in multiply
#   s1 = y * np.log(h)
# (1057,)
# (645,)
# (0,)
# (634,)
# validación = 47.21746575342466
# (1020,)
# (622,)
# (0,)
# (694,)
# prueba = 48.50171232876712
# (604,)
# (580,)
# (575,)
# (577,)
# validación = 61.044520547945204
# (625,)
# (534,)
# (560,)
# (617,)
# prueba = 62.0291095890411
# (1881,)
# (0,)
# (0,)
# (455,)
# validación = 27.95376712328767
# (1932,)
# (0,)
# (0,)
# (404,)
# prueba = 28.25342465753425
# (157,)
# (1248,)
# (162,)
# (769,)
# validación = 27.397260273972602
# (151,)
# (1292,)
# (152,)
# (741,)
# prueba = 27.397260273972602
# (792,)
# (692,)
# (262,)
# (590,)
# validación = 57.234589041095894
# (774,)
# (696,)
# (260,)
# (606,)
# prueba = 58.56164383561644
# (637,)
# (176,)
# (911,)
# (612,)
# validación = 48.0736301369863
# (662,)
# (157,)
# (890,)
# (627,)
# prueba = 48.67294520547945
# (1790,)
# (187,)
# (75,)
# (284,)
# validación = 24.743150684931507
# (1797,)
# (163,)
# (78,)
# (298,)
# prueba = 25.89897260273973
# (732,)
# (0,)
# (0,)
# (1604,)
# validación = 23.84417808219178
# (673,)
# (0,)
# (0,)
# (1663,)
# prueba = 25.0
# (747,)
# (949,)
# (0,)
# (640,)
# validación = 50.042808219178085
# (767,)
# (925,)
# (0,)
# (644,)
# prueba = 51.71232876712328
# (592,)
# (534,)
# (634,)
# (576,)
# validación = 68.57876712328768
# (633,)
# (483,)
# (606,)
# (614,)
# prueba = 70.46232876712328
# (97,)
# (0,)
# (0,)
# (2239,)
# validación = 23.715753424657535
# (80,)
# (0,)
# (0,)
# (2256,)
# prueba = 25.81335616438356
# (0,)
# (1,)
# (2164,)
# (171,)
# validación = 28.767123287671232
# (0,)
# (0,)
# (2152,)
# (184,)
# prueba = 30.09417808219178
# (718,)
# (871,)
# (169,)
# (578,)
# validación = 60.659246575342465
# (716,)
# (828,)
# (177,)
# (615,)
# prueba = 62.11472602739726
# (615,)
# (487,)
# (693,)
# (541,)
# validación = 64.08390410958904
# (604,)
# (474,)
# (673,)
# (585,)
# prueba = 66.30993150684932
# (0,)
# (0,)
# (1260,)
# (1076,)
# validación = 25.214041095890412
# (0,)
# (0,)
# (1306,)
# (1030,)
# prueba = 27.18321917808219
# (288,)
# (1036,)
# (1,)
# (1011,)
# validación = 30.0513698630137
# (294,)
# (1027,)
# (1,)
# (1014,)
# prueba = 31.164383561643838
# (280,)
# (720,)
# (749,)
# (587,)
# validación = 54.494863013698634
# (301,)
# (686,)
# (760,)
# (589,)
# prueba = 54.53767123287672
# (611,)
# (571,)
# (591,)
# (563,)
# validación = 74.0582191780822
# (607,)
# (529,)
# (612,)
# (588,)
# prueba = 75.4708904109589
# (0,)
# (1796,)
# (0,)
# (540,)
# validación = 26.96917808219178
# (0,)
# (1774,)
# (0,)
# (562,)
# prueba = 28.25342465753425
# (243,)
# (0,)
# (889,)
# (1204,)
# validación = 28.08219178082192
# (215,)
# (0,)
# (908,)
# (1213,)
# prueba = 27.95376712328767
# (618,)
# (837,)
# (298,)
# (583,)
# validación = 60.14554794520548
# (638,)
# (807,)
# (274,)
# (617,)
# prueba = 60.445205479452056
# (618,)
# (993,)
# (137,)
# (588,)
# validación = 60.18835616438356
# (577,)
# (1000,)
# (151,)
# (608,)
# prueba = 59.76027397260274
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (242,)
# (1809,)
# (0,)
# (285,)
# validación = 27.482876712328768
# (259,)
# (1779,)
# (0,)
# (298,)
# prueba = 27.78253424657534
# (837,)
# (791,)
# (156,)
# (552,)
# validación = 57.79109589041096
# (848,)
# (721,)
# (174,)
# (593,)
# prueba = 57.705479452054796
# (651,)
# (554,)
# (581,)
# (550,)
# validación = 69.0068493150685
# (578,)
# (561,)
# (634,)
# (563,)
# prueba = 68.15068493150685
# (1329,)
# (144,)
# (0,)
# (863,)
# validación = 25.59931506849315
# (1369,)
# (152,)
# (0,)
# (815,)
# prueba = 27.825342465753423
# (0,)
# (1203,)
# (0,)
# (1133,)
# validación = 24.57191780821918
# (0,)
# (1159,)
# (0,)
# (1177,)
# prueba = 26.32705479452055
# (516,)
# (586,)
# (658,)
# (576,)
# validación = 54.45205479452054
# (514,)
# (539,)
# (680,)
# (603,)
# prueba = 57.27739726027398
# (614,)
# (550,)
# (620,)
# (552,)
# validación = 61.00171232876712
# (590,)
# (581,)
# (598,)
# (567,)
# prueba = 63.18493150684932
# (766,)
# (73,)
# (1142,)
# (355,)
# validación = 25.4708904109589
# (743,)
# (91,)
# (1150,)
# (352,)
# prueba = 25.17123287671233
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (262,)
# (619,)
# (876,)
# (579,)
# validación = 59.24657534246576
# (250,)
# (599,)
# (884,)
# (603,)
# prueba = 59.46061643835616
# (605,)
# (573,)
# (606,)
# (552,)
# validación = 68.57876712328768
# (578,)
# (526,)
# (650,)
# (582,)
# prueba = 70.9332191780822
# (992,)
# (260,)
# (5,)
# (1079,)
# validación = 25.214041095890412
# (1007,)
# (216,)
# (6,)
# (1107,)
# prueba = 28.08219178082192
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1081,)
# (623,)
# (0,)
# (632,)
# validación = 49.2722602739726
# (1042,)
# (641,)
# (0,)
# (653,)
# prueba = 51.62671232876712
# (591,)
# (502,)
# (677,)
# (566,)
# validación = 66.05308219178082
# (606,)
# (455,)
# (686,)
# (589,)
# prueba = 68.36472602739725
# (0,)
# (2336,)
# (0,)
# (0,)
# validación = 25.85616438356164
# (0,)
# (2336,)
# (0,)
# (0,)
# prueba = 24.529109589041095
# (1110,)
# (413,)
# (0,)
# (813,)
# validación = 25.0
# (1062,)
# (436,)
# (0,)
# (838,)
# prueba = 26.1986301369863
# (1146,)
# (553,)
# (58,)
# (579,)
# validación = 51.369863013698634
# (1126,)
# (555,)
# (51,)
# (604,)
# prueba = 53.296232876712324
# (662,)
# (695,)
# (414,)
# (565,)
# validación = 62.457191780821915
# (671,)
# (638,)
# (415,)
# (612,)
# prueba = 60.91609589041096
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-98332ab105c0> in <module>
#      21
#      22                         for i in range(len(iteraciones)):
# ---> 23                             p1, p2 = r.entrenar(Ex, y_onehot, Vx, Vy, Px, Py, L, iteraciones[i], INIT_EPSILON)
#      24                             validaciones.append(p1)
#      25                             pruebas.append(p2)
#
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py in entrenar(self, X, y, Vx, Vy, Px, Py, reg, iters, init)
#     205         # calculo del minimo
#     206
# --> 207         fmin = minimize(fun = self.backprop , x0 = pesos_ravel , args = (X,y,reg),
#     208                         method = 'TNC' , jac = True , options = {'maxiter' : iters})
#     209
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     618                                 callback=callback, **options)
#     619     elif meth == 'tnc':
# --> 620         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     621                              **options)
#     622     elif meth == 'cobyla':
#
# ~\anaconda3\lib\site-packages\scipy\optimize\tnc.py in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, finite_diff_rel_step, maxfun, **unknown_options)
#     412             maxfun = max(100, 10*len(x0))
#     413
# --> 414     rc, nf, nit, x = moduleTNC.minimize(func_and_grad, x0, low, up, scale,
#     415                                         offset, messages, maxCGit, maxfun,
#     416                                         eta, stepmx, accuracy, fmin, ftol,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_and_grad(self, x)
#     198         if not np.array_equal(x, self.x):
#     199             self._update_x_impl(x)
# --> 200         self._update_fun()
#     201         self._update_grad()
#     202         return self.f, self.g
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~\anaconda3\lib\site-packages\scipy\optimize\optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py in backprop(self, params_rn, X, y, reg)
#     160         matrices_pesos = self.desenlazado(params_rn)
#     161
# --> 162         deltas = self.gradiente_reg(X,y,reg, matrices_pesos)
#     163         coste = self.coste_reg(X,y,reg, matrices_pesos)
#     164
#
# D:\UNI\3ºAño\Notebook\Proyecto AA\creador_redes.py in gradiente_reg(self, X, y, reg, matrices_pesos)
#      93             for j in range(len(activ)-3, 1, -1):
#      94                 g_aux = activ[j] * ( 1 - activ[j])
# ---> 95                 daux = np.dot(matrices_pesos[j].T, daux[1:]) * g_aux
#      96                 Deltas[j - 1] = Deltas[j - 1] + np.dot(daux[1:,np.newaxis], activ[j-1][np.newaxis, :])
#      97
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
63,63,63,56,42    72,73
63,63,63,56,35    74,72
63,63,63,56,21    71,72
63,63,63,49,35    70,73
63,63,63,42,28    74,75

# %% [markdown]
# ## prueba CheckNNGradient

# %%
from checkNNGradients import checkNNGradients

r = red_neuronal(1, [5], 0.12, 3, 3)

checkNNGradients (r.backprop , 0.1)
# Out:
# grad shape:  (38,)
# num grad shape:  (38,)
# array([ 2.86006259e-07, -1.44926309e-08,  5.17625875e-08,  7.04249071e-08,
#        -3.26235469e-07,  5.95653303e-08, -1.21742581e-07, -1.91150149e-07,
#        -5.32065243e-07,  1.04927864e-07, -2.56773482e-07, -3.82463637e-07,
#        -3.06558803e-07,  3.85829526e-08, -1.04657968e-07, -1.51689812e-07,
#         2.23858079e-07, -3.65876015e-08,  7.74611560e-08,  1.20305060e-07,
#         8.74971631e-07,  4.50207454e-07,  4.00482634e-07,  4.47256173e-07,
#         4.39713644e-07,  5.27031399e-07,  9.12219686e-07,  5.53073506e-07,
#         3.42804977e-07,  4.81445995e-07,  5.05301518e-07,  4.87923142e-07,
#         1.14645184e-06,  5.89118625e-07,  4.08370178e-07,  7.14643129e-07,
#         4.95463758e-07,  5.42036173e-07])
