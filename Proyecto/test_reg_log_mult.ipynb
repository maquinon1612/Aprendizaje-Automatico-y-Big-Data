# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("0.csv")
df.hist(figsize=(10, 10)) 
plt.tight_layout()

# %%
df = pd.read_csv("1.csv")
df.hist(figsize=(10, 10)) 
plt.tight_layout()

# %%
df = pd.read_csv("1.csv")
df.hist(figsize=(10, 10)) 
plt.tight_layout()

# %%
df = pd.read_csv("1.csv")
df.hist(figsize=(10, 10)) 
plt.tight_layout()

# %% [markdown]
# Distribución de todos los valores se asemeja a una normal

# %%
from regularización import *

# %%
X, Y, _ = cargarDatos()
Theta = oneVsAll(X.to_numpy(), Y.to_numpy(), 4, 0.1)
# Out:
# coste: 0.6157691691715046
# coste: 0.6200571580352865
# coste: 0.6216326117187084
# coste: 0.6207739401196667

# %%
evalua()
# Out:
# coste: 0.6157691691496981
# coste: 0.6200571580592719
# coste: 0.6216326117251164
# coste: 0.620773940123088
# Porcentaje de aciertos con lambda = 0.01 :  81.12 %
# coste: 0.6157691691541148
# coste: 0.6200571580538378
# coste: 0.6216326117236943
# coste: 0.6207739401222431
# Porcentaje de aciertos con lambda = 0.03 :  81.12 %
# coste: 0.6157691691715046
# coste: 0.6200571580352865
# coste: 0.6216326117187084
# coste: 0.6207739401196667
# Porcentaje de aciertos con lambda = 0.1 :  81.12 %
# coste: 0.6157691692265499
# coste: 0.6200571579851945
# coste: 0.6216326117069609
# coste: 0.620773940115236
# Porcentaje de aciertos con lambda = 0.3 :  81.12 %
# coste: 0.6157691694834638
# coste: 0.6200571578499167
# coste: 0.6216326116937435
# coste: 0.6207739401309323
# Porcentaje de aciertos con lambda = 1 :  81.12 %
# coste: 0.6157691707697978
# coste: 0.620057157804164
# coste: 0.6216326118964183
# coste: 0.620773940450437
# Porcentaje de aciertos con lambda = 3 :  81.12 %
# coste: 0.6157691816974815
# coste: 0.6200571616280699
# coste: 0.6216326154040115
# coste: 0.6207739447623146
# Porcentaje de aciertos con lambda = 10 :  81.14 %
# coste: 0.6157692677010393
# coste: 0.620057206685978
# coste: 0.6216326493012091
# coste: 0.6207739843302594
# Porcentaje de aciertos con lambda = 30 :  81.12 %

# %% [markdown]
# Mejores = 9,10,11
